# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/flores-santali-test/dev.sat_Olck
# /kaggle/input/flores-santali-test/dev.eng_Latn
# /kaggle/input/ai4bharat-santali-train/train.sat_Olck
# /kaggle/input/ai4bharat-santali-train/train.eng_Latn

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !pip install -U pip
# !git clone https://github.com/pytorch/fairseq.git
# %cd fairseq
#!git checkout v0.10.2
##!python -m pip install --user ./
# !pip install --editable .
# %cd ..
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (23.3.2)
# Collecting pip
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 32.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.2
#     Uninstalling pip-23.3.2:
#       Successfully uninstalled pip-23.3.2
# Successfully installed pip-24.0
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35203, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 35203 (delta 66), reused 80 (delta 48), pack-reused 35083
# Receiving objects: 100% (35203/35203), 25.23 MiB | 32.61 MiB/s, done.
# Resolving deltas: 100% (25556/25556), done.
# /kaggle/working/fairseq
# Obtaining file:///kaggle/working/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.16.0)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (3.0.8)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.21.3 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.26.4)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2023.12.25)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2)
#   Downloading sacrebleu-2.4.2-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (4.66.4)
# Collecting bitarray (from fairseq==0.12.2)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: torchaudio>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.1.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.2.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (21.3)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.* in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (6.0.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (4.9.0)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (5.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (2024.3.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi->fairseq==0.12.2) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->fairseq==0.12.2) (3.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13->fairseq==0.12.2) (1.3.0)
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 7.6 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 8.0 MB/s eta 0:00:00
# Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 16.0 MB/s eta 0:00:00
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-0.editable-cp310-cp310-linux_x86_64.whl size=9571 sha256=97b1209e5e7e7d3b9c8ece8f93f664cabf8e98259bc1ce5627f4b5a413e133f6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k753u_pg/wheels/67/69/06/aa788a7d879a7513f5f2e5c6d56825b6813783cb55ac5c7f8d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141210 sha256=5c30a4ccb3e20c32af2213a26b64d22529ce4228d3744e23dac838ec08b02d7a
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: bitarray, antlr4-python3-runtime, portalocker, omegaconf, sacrebleu, hydra-core, fairseq
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.9.2 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.8.2 sacrebleu-2.4.2
# /kaggle/working

# %%
# !nvidia-smi
# Out:
# Tue Jun 18 17:26:30 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla P100-PCIE-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0              27W / 250W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install git+https://github.com/vmujadia/tokenizer.git --upgrade
# Out:
# Collecting git+https://github.com/vmujadia/tokenizer.git
#   Cloning https://github.com/vmujadia/tokenizer.git to /tmp/pip-req-build-b1l7ml26
#   Running command git clone --filter=blob:none --quiet https://github.com/vmujadia/tokenizer.git /tmp/pip-req-build-b1l7ml26
#   Resolved https://github.com/vmujadia/tokenizer.git to commit 93cd09b81702108a51c08c9796fd1cc941a1b98b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (2024.2.2)
# Building wheels for collected packages: IL-Tokenizer
#   Building wheel for IL-Tokenizer (setup.py) ... done
#   Created wheel for IL-Tokenizer: filename=IL_Tokenizer-0.0.2-py3-none-any.whl size=7225 sha256=b382326d3f8a6f4c3075d4dc117989d94e002fb0438d1c17d4ff0e9d2bdcb62c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ernjjbap/wheels/9a/fb/5b/3d75bfde8561726121c09f0f0a83389c05312df8a513808c41
# Successfully built IL-Tokenizer
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: IL-Tokenizer
# Successfully installed IL-Tokenizer-0.0.2

# %%
# !git clone https://github.com/moses-smt/mosesdecoder.git
# Out:
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 148459, done.
# remote: Counting objects: 100% (887/887), done.
# remote: Compressing objects: 100% (366/366), done.
# remote: Total 148459 (delta 565), reused 797 (delta 517), pack-reused 147572
# Receiving objects: 100% (148459/148459), 129.99 MiB | 25.51 MiB/s, done.
# Resolving deltas: 100% (114591/114591), done.

# %%
# !git clone https://github.com/rsennrich/subword-nmt.git
# Out:
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 600, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 600 (delta 10), reused 12 (delta 4), pack-reused 576
# Receiving objects: 100% (600/600), 253.58 KiB | 7.68 MiB/s, done.
# Resolving deltas: 100% (359/359), done.

# %%
# !ls mosesdecoder/scripts/training/clean-corpus-n.perl
# Out:
# mosesdecoder/scripts/training/clean-corpus-n.perl

# %%
# Use the datasets already downloaded in the Kaggle notebook
# !cp /kaggle/input/ai4bharat-santali-train/train.eng_Latn train.tgt
# !cp /kaggle/input/ai4bharat-santali-train/train.sat_Olck train.src
# !cp /kaggle/input/flores-santali-test/dev.eng_Latn valid.tgt
# !cp /kaggle/input/flores-santali-test/dev.sat_Olck valid.src

# %%
print ('Data Stats')
! wc -l train.*
! wc -l valid.*
# Out:
# Data Stats
#   22536 train.src
#   22536 train.tgt
#   45072 total
#    997 valid.src
#    997 valid.tgt
#   1994 total

# %%
from ilstokenizer import tokenizer
import codecs

def to_tokenize_and_lower(input_path, output_path):
  outfile = open(output_path, 'w')
  for line in codecs.open(input_path):
    line = line.strip()
    line = tokenizer.tokenize(line).lower()
    #print (line)
    outfile.write(line+'\n')
  outfile.close()

# %%
to_tokenize_and_lower('train.src','train.src.tkn')
to_tokenize_and_lower('train.tgt','train.tgt.tkn')

to_tokenize_and_lower('valid.src','valid.src.tkn')
to_tokenize_and_lower('valid.tgt','valid.tgt.tkn')

# %%
! cat train.src.tkn > train.all.tkn
! cat train.tgt.tkn >> train.all.tkn

# %%
! perl mosesdecoder/scripts/training/clean-corpus-n.perl -ratio 1.5 train src.tkn tgt.tkn train_filtered 1 250
# Out:
# clean-corpus.perl: processing train.src.tkn & .tgt.tkn to train_filtered, cutoff 1-250, ratio 1.5
# ..
# Input sentences: 22536  Output sentences:  21996

# %%
print ('Data Stats')
! wc -l train*
! wc -l valid*
# Out:
# Data Stats
#    45072 train.all.tkn
#    22536 train.src
#    22536 train.src.tkn
#    22536 train.tgt
#    22536 train.tgt.tkn
#    21996 train_filtered.src.tkn
#    21996 train_filtered.tgt.tkn
#   179208 total
#    997 valid.src
#    997 valid.src.tkn
#    997 valid.tgt
#    997 valid.tgt.tkn
#   3988 total

# %%
# !python subword-nmt/subword_nmt/learn_bpe.py -s 7500 < train.all.tkn > train.codes
# Out:
# 100%|######################################| 7500/7500 [00:17<00:00, 430.69it/s]

# %%
! head -n 10 train.codes
# Out:
# #version: 0.2
# t h
# ᱟ ᱹ
# ᱟ ᱜ</w>
# th e</w>
# i n
# a n
# ᱠ ᱟ
# ᱨ ᱮ
# ᱟ ᱨ</w>

# %%
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < train.src.tkn > train.sat
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < train.tgt.tkn > train.en

# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < valid.src.tkn > valid.sat
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < valid.tgt.tkn > valid.en

# %%
! head -n 10 train.en
# Out:
# the delhi division of punjab province formed the bul@@ k of haryana .
# they te@@ ach pali and kh@@ am@@ ti scrip@@ ts in addition to typical education subj@@ ects .
# the western part of the plateau , compri@@ sing the gar@@ o hills region with lower el@@ ev@@ ations , experi@@ ences high temper@@ atures for most of the year .
# many online sel@@ l@@ ers , like am@@ az@@ on and e@@ bay , offer a huge variety of products for lower prices than you can find them in - store .
# notable among them are north east today , g pl@@ us , northeast now , ti@@ me@@ 8 etc .
# the king himself composed an ep@@ ic telugu po@@ em , am@@ uk@@ tam@@ aly@@ ada .
# ray was rel@@ uc@@ tant to go , due to his f@@ ond@@ ness for cal@@ cut@@ ta and the low regar@@ d for the in@@ tel@@ l@@ ec@@ tual life at s@@ ant@@ in@@ i@@ ke@@ t@@ an .
# a new railway line is being l@@ aid west@@ wards from ag@@ art@@ ala to ak@@ ha@@ ura in bangladesh .
# kashmir university located in s@@ rin@@ agar is the main university in the territory .
# major institu@@ tions of higher education are n@@ it s@@ rin@@ agar , i@@ it jammu , i@@ i@@ m jammu , ni@@ ft s@@ rin@@ agar , and i@@ h@@ m s@@ rin@@ agar .

# %%
! head -n 10 train.sat
# Out:
# ᱯᱟᱧᱡᱟᱵᱽ ᱯᱚᱱᱚᱛ ᱨᱮᱭᱟᱜ ᱫᱤᱞᱞᱤ ᱛᱷᱚᱱᱚᱛ ᱦᱚᱨᱤᱭᱟᱱᱟ ᱨᱮᱭᱟᱜ ᱥᱟᱸᱜᱮ ᱦᱟᱹᱴᱤ@@ ᱧ@@ ᱮ ᱛᱮᱭᱟᱨ ᱞᱮᱫᱟ ᱾
# ᱩᱱᱠᱩ ᱫᱚ ᱥᱟᱫᱷᱟᱨᱚᱱ ᱥᱮᱪᱮᱫ ᱥᱟᱛᱟᱢ ᱪᱷᱟᱰᱟ ᱦᱚᱸ ᱯᱟᱹ@@ ᱞᱤ ᱟᱨ ᱠᱷ@@ ᱟᱢ@@ ᱛᱤ ᱞᱤᱯᱤ ᱠᱚ ᱪᱮᱫ ᱟ@@ ᱠᱚᱣᱟ ᱾
# ᱢᱟᱞ@@ ᱵᱷᱩᱢᱤ ᱯᱚᱪᱷᱤᱢ ᱯᱟᱦᱟᱴᱟ ᱨᱮ , ᱜᱟ@@ ᱨᱳ ᱯᱚᱨ@@ ᱯᱚ@@ ᱛᱟ ᱴᱚᱴᱷᱟ ᱨᱮ ᱞᱟᱛᱟᱨ ᱪᱮᱛᱟᱱ ᱥᱚ@@ ᱦᱚᱸ , ᱥᱮᱨᱢᱟ ᱨᱮᱭᱟᱜ ᱟᱭᱢᱟᱜᱟᱱ ᱚᱠᱛᱚ ᱨᱮ ᱩᱥᱩᱞ ᱞᱚᱞᱚᱥᱚᱝ ᱧᱮᱞ ᱧᱟᱢᱚᱜᱼᱟ ᱾
# ᱟᱹᱰᱤᱜᱟᱱ ᱚᱱᱞᱟᱭᱤᱱ ᱟᱠᱷ@@ ᱨᱤ@@ ᱧᱤᱭᱟᱹ , ᱡᱮᱞᱮᱠᱟ ᱟ@@ ᱢᱟ@@ ᱡᱚᱱ ᱟᱨ ᱤ@@ ᱵᱮ ᱟᱢ ᱫᱚᱠᱟᱱ ᱨᱮ ᱡᱟᱦᱟ@@ ᱢ ᱧᱟᱢᱟ ᱚᱱᱟ ᱠᱷᱚᱱ@@ ᱦᱚᱸ ᱠᱚᱢ ᱫᱟᱢ ᱨᱮᱭᱟᱜ ᱟᱹᱰᱤ ᱞᱮᱠᱟᱱ ᱫᱩᱨᱤᱵᱽ ᱮᱢᱚᱜᱼᱟ ᱾
# ᱱᱚᱶᱟ ᱢᱩᱫᱽᱨᱮ ᱧᱩ@@ ᱢᱟᱱᱟᱜ ᱦᱩᱭᱩᱜ ᱠᱟᱱᱟ ᱱᱚᱨ@@ ᱛᱷ ᱤᱥᱴ ᱴᱩ@@ ᱰᱮ , ᱡᱤ ᱯ@@ ᱞᱟᱥ , ᱱᱚᱨ@@ ᱛᱷ@@ ᱼ@@ ᱤᱥᱴ ᱱᱟᱣ , ᱴᱟᱭᱤ@@ ᱢ ᱘ ᱮᱢᱟ@@ ᱱᱟᱜ ᱾
# ᱨᱟᱡᱟ ᱟᱡ@@ ᱜᱮ ᱢᱤᱫᱴᱮᱱ ᱢᱟᱦᱟ ᱚᱱᱚ@@ ᱲ@@ ᱦᱮᱸ ᱛᱮᱞᱮᱜᱩ ᱚᱱᱚ@@ ᱲ@@ ᱦᱮᱸ , ᱟ@@ ᱢᱩ@@ ᱠ@@ ᱛᱚ@@ ᱢᱟᱞ@@ ᱞᱚ@@ ᱫᱟ ᱚᱞ ᱞᱮᱫᱟᱭ ᱾
# ᱠᱚᱞᱠᱟᱛᱟ ᱥᱟᱶ ᱟᱡᱟᱜ ᱡᱚᱯᱚᱲᱟᱣ ᱟᱨ ᱥᱟᱱ@@ ᱛᱤ@@ ᱱᱤ@@ ᱠᱮ@@ ᱛᱚᱱ ᱨᱮ ᱵᱩ@@ ᱫᱽ@@ ᱫᱷᱤ@@ ᱡᱤ@@ ᱵᱤ ᱡᱤᱣ@@ ᱚᱱ ᱥᱟᱶ ᱠᱚᱢ ᱢᱟᱱᱚᱛ ᱨᱮᱱᱟᱜ ᱚᱡᱮᱛᱮ ᱥᱚ@@ ᱹ@@ ᱛᱛᱚ@@ ᱡᱤᱛ ᱪᱟᱞᱟᱣ ᱞᱟᱹᱜᱤᱫ ᱛᱮ ᱨᱟᱹ@@ ᱡᱤ ᱵᱟᱝ@@ ᱮ ᱛᱟᱦᱮᱸᱠᱟᱱᱟ ᱾
# ᱵᱟᱝᱞᱟᱫᱮᱥ ᱨᱮᱭᱟᱜ ᱟᱜᱚ@@ ᱨ@@ ᱛᱚ@@ ᱞᱟ ᱠᱷᱚᱱ ᱟᱠᱷᱟ@@ ᱩ@@ ᱲᱟ ᱫᱷᱟᱹᱵᱤᱡ ᱯᱚᱪᱷᱤᱢ ᱱᱟᱠᱷᱟ ᱥᱮᱫ ᱢᱤᱫᱴᱟᱝ ᱱᱟᱶᱟ ᱨᱮᱞ@@ ᱞᱟᱭᱤᱱ ᱛᱷᱟᱯᱚᱱ ᱦᱩᱭᱩᱜ ᱠᱟᱱᱟ ᱾
# ᱥᱨᱤ@@ ᱱᱚᱜᱚᱨ ᱨᱮ ᱢᱮᱱᱟᱜ ᱠᱟᱥᱢᱤᱨ ᱡᱮᱜᱮᱫ ᱵᱤᱨᱫᱟᱹᱜᱟᱲ ᱫᱚ ᱱᱚᱶᱟ ᱴᱚᱴᱷᱟ ᱨᱮᱭᱟᱜ ᱢᱟᱨᱟᱝ ᱡᱮᱜᱮᱫ ᱵᱤᱨᱫᱟᱹᱜᱟᱲ ᱠᱟᱱᱟ ᱾
# ᱞᱟᱯᱷᱟᱝ ᱥᱮᱪᱮᱫ ᱨᱮᱭᱟᱜ ᱢᱩᱬᱩᱫ ᱟᱥᱲᱟ ᱠᱚᱫᱚ ᱦᱩᱭᱩᱜ ᱠᱟᱱᱟ ᱮᱱ ᱟᱭ ᱴᱤ ᱥᱨᱤ@@ ᱱᱚᱜᱚᱨ , ᱟᱭ ᱟᱭ ᱴᱤ ᱡᱚᱢ@@ ᱢᱩ , ᱟᱭ ᱟᱭ ᱴᱤ ᱡᱚᱢ@@ ᱢᱩ , ᱮᱱ ᱟᱭ ᱮᱯᱷ ᱴᱤ ᱥᱨᱤ@@ ᱱᱚᱜᱚᱨ , ᱟᱨ ᱟᱭ ᱮ@@ ᱭᱤᱪ ᱮᱢ ᱥᱨᱤ@@ ᱱᱚᱜᱚᱨ ᱾

# %%
import os
os.environ['PYTHONPATH'] += ":/content/fairseq/"

! echo $PYTHONPATH
# Out:
# /kaggle/lib/kagglegym:/kaggle/lib:/content/fairseq/

# %%
! python fairseq/fairseq_cli/preprocess.py \
    --joined-dictionary \
    --source-lang sat --target-lang en \
    --trainpref train --validpref valid --testpref valid \
    --destdir data-bin/trial --thresholdtgt 0 --thresholdsrc 0 \
    --workers 20
# Out:
# 2024-06-18 17:32:14.485089: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-18 17:32:14.485203: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-18 17:32:14.617734: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /kaggle/working/fairseq/fairseq/tasks/multires_hubert_pretraining.py:154: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   dictionaries = [ (Dictionary.load(f"{label_dir}/dict.{label}.txt") if label is not "" else None ) for label in self.cfg.labels]
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
ls data-bin/trial
# Out:
# dict.en.txt         test.sat-en.sat.bin   train.sat-en.sat.idx
# dict.sat.txt        test.sat-en.sat.idx   valid.sat-en.en.bin
# preprocess.log      train.sat-en.en.bin   valid.sat-en.en.idx
# test.sat-en.en.bin  train.sat-en.en.idx   valid.sat-en.sat.bin
# test.sat-en.en.idx  train.sat-en.sat.bin  valid.sat-en.sat.idx

# %%
! python fairseq/fairseq_cli/train.py --fp16 \
    data-bin/trial \
    --source-lang sat --target-lang en \
    --arch transformer_iwslt_de_en --share-all-embeddings \
    --encoder-embed-dim	128 --encoder-ffn-embed-dim	128 \
    --encoder-layers	2 --encoder-attention-heads	2 \
    --decoder-embed-dim	128 --decoder-ffn-embed-dim	128 \
    --decoder-layers	2 --decoder-attention-heads	2 \
    --dropout 0.3 --weight-decay 0.0 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 0.01 --lr-scheduler inverse_sqrt --warmup-updates 10 \
    --max-tokens 4096 --update-freq 16 \
    --max-update 1500 \
    --keep-last-epochs	10 \
    --save-dir trained_models
# Out:
# 2024-06-18 17:34:37.833358: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-18 17:34:37.833407: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-18 17:34:37.834970: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# epoch 002:   0%|                                         | 0/13 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# epoch 002:  92%|█████████████████████████████▌  | 12/13 [00:06<00:00,  2.31it/s]
# epoch 002 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.59it/s]
# epoch 002 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.98it/s]
# epoch 003:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.25it/s]
# epoch 003 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 58.70it/s]
# epoch 003 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.86it/s]
# epoch 004:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 004 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 47.17it/s]
# epoch 004 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 52.59it/s]
# epoch 005:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.32it/s]
# epoch 005 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 005 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.05it/s]
# epoch 005 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.68it/s]
# epoch 006:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.26it/s]
# epoch 006 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 006 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 58.47it/s]
# epoch 006 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.48it/s]
# epoch 007:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 007 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 007 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 59.83it/s]
# epoch 007 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 64.53it/s]
# epoch 008:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.21it/s]
# epoch 008 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 008 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.18it/s]
# epoch 008 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.01it/s]
# epoch 009:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 009 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 009 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.55it/s]
# epoch 009 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.88it/s]
# epoch 010:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 010 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 010 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.71it/s]
# epoch 010 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.10it/s]
# epoch 011:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.36it/s]
# epoch 011 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 011 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.40it/s]
# epoch 011 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.55it/s]
# epoch 012:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.25it/s]
# epoch 012 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 012 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.48it/s]
# epoch 012 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 64.08it/s]
# epoch 013:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.14it/s]
# epoch 013 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 013 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 44.00it/s]
# epoch 013 | valid on 'valid' subset:  67%|████  | 10/15 [00:00<00:00, 46.44it/s]
# epoch 014:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.26it/s]
# epoch 014 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 014 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 54.87it/s]
# epoch 014 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.93it/s]
# epoch 015:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 015 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 015 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.52it/s]
# epoch 015 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.07it/s]
# epoch 016:  92%|▉| 12/13 [00:05<00:00,  2.33it/s, loss=10.272, nll_loss=9.78, pp
# epoch 016 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 016 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.38it/s]
# epoch 016 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.19it/s]
# epoch 017:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.33it/s]
# epoch 017 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 017 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.51it/s]
# epoch 017 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.09it/s]
# epoch 018:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.26it/s]
# epoch 018 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 018 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 44.66it/s]
# epoch 018 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 49.19it/s]
# epoch 019:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.32it/s]
# epoch 019 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 019 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.25it/s]
# epoch 019 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.40it/s]
# epoch 020:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 020 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 020 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.37it/s]
# epoch 020 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 60.81it/s]
# epoch 021:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.29it/s]
# epoch 021 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 021 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.32it/s]
# epoch 021 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 66.52it/s]
# epoch 022:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 022 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 022 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 56.96it/s]
# epoch 022 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.84it/s]
# epoch 023:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.26it/s]
# epoch 023 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 023 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.66it/s]
# epoch 023 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.97it/s]
# epoch 024:  92%|▉| 12/13 [00:05<00:00,  2.28it/s, loss=10.09, nll_loss=9.574, pp
# epoch 024 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 024 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 48.16it/s]
# epoch 024 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 53.57it/s]
# epoch 025:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 025 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 025 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.31it/s]
# epoch 025 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 60.85it/s]
# epoch 026:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 026 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 026 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.30it/s]
# epoch 026 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 60.47it/s]
# epoch 027:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.23it/s]
# epoch 027 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 027 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 48.75it/s]
# epoch 027 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 53.37it/s]
# epoch 028:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 028 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 028 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.46it/s]
# epoch 028 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.53it/s]
# epoch 029:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.29it/s]
# epoch 029 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 029 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.66it/s]
# epoch 029 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.44it/s]
# epoch 030:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 030 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 030 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 47.03it/s]
# epoch 030 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 57.47it/s]
# epoch 031:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.26it/s]
# epoch 031 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 031 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 56.34it/s]
# epoch 031 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.71it/s]
# epoch 032:  92%|▉| 12/13 [00:05<00:00,  2.25it/s, loss=9.834, nll_loss=9.276, pp
# epoch 032 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 032 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.20it/s]
# epoch 032 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.18it/s]
# epoch 033:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.33it/s]
# epoch 033 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 033 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.57it/s]
# epoch 033 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.26it/s]
# epoch 034:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 034 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 034 | valid on 'valid' subset:  47%|███▎   | 7/15 [00:00<00:00, 58.71it/s]
# epoch 034 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 64.34it/s]
# epoch 035:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 035 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 035 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 58.06it/s]
# epoch 035 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.82it/s]
# epoch 036:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 036 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 036 | valid on 'valid' subset:  47%|███▎   | 7/15 [00:00<00:00, 64.92it/s]
# epoch 036 | valid on 'valid' subset: 100%|██████| 15/15 [00:00<00:00, 71.32it/s]
# epoch 037:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 037 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 037 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.18it/s]
# epoch 037 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 56.86it/s]
# epoch 038:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 038 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 038 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 48.02it/s]
# epoch 038 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 54.56it/s]
# epoch 039:  92%|▉| 12/13 [00:05<00:00,  2.26it/s, loss=9.451, nll_loss=8.828, pp
# epoch 039 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 039 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.25it/s]
# epoch 039 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 60.61it/s]
# epoch 040:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.35it/s]
# epoch 040 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 040 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.34it/s]
# epoch 040 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 66.07it/s]
# epoch 041:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 041 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 041 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.21it/s]
# epoch 041 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.31it/s]
# epoch 042:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 042 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 042 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 48.43it/s]
# epoch 042 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 54.48it/s]
# epoch 043:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.29it/s]
# epoch 043 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 043 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 56.64it/s]
# epoch 043 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 67.31it/s]
# epoch 044:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.15it/s]
# epoch 044 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 044 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.33it/s]
# epoch 044 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.83it/s]
# epoch 045:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 045 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 045 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.06it/s]
# epoch 045 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.18it/s]
# epoch 046:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.34it/s]
# epoch 046 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 046 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 56.77it/s]
# epoch 046 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 68.26it/s]
# epoch 047:  92%|▉| 12/13 [00:05<00:00,  2.34it/s, loss=9.162, nll_loss=8.491, pp
# epoch 047 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 047 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 58.42it/s]
# epoch 047 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 64.88it/s]
# epoch 048:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 048 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 048 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.76it/s]
# epoch 048 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.81it/s]
# epoch 049:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 049 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 049 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 46.45it/s]
# epoch 049 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 49.60it/s]
# epoch 050:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.18it/s]
# epoch 050 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 050 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.81it/s]
# epoch 050 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.82it/s]
# epoch 051:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 051 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 051 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 54.63it/s]
# epoch 051 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.12it/s]
# epoch 052:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.32it/s]
# epoch 052 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 052 | valid on 'valid' subset:  47%|███▎   | 7/15 [00:00<00:00, 65.36it/s]
# epoch 052 | valid on 'valid' subset: 100%|██████| 15/15 [00:00<00:00, 70.84it/s]
# epoch 053:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.35it/s]
# epoch 053 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 053 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.43it/s]
# epoch 053 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.57it/s]
# epoch 054:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.29it/s]
# epoch 054 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 054 | valid on 'valid' subset:  47%|███▎   | 7/15 [00:00<00:00, 63.73it/s]
# epoch 054 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 64.68it/s]
# epoch 055:  92%|▉| 12/13 [00:05<00:00,  2.27it/s, loss=8.957, nll_loss=8.249, pp
# epoch 055 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 055 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 54.20it/s]
# epoch 055 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.08it/s]
# epoch 056:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.24it/s]
# epoch 056 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 056 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.59it/s]
# epoch 056 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 58.00it/s]
# epoch 057:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.25it/s]
# epoch 057 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 057 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 58.71it/s]
# epoch 057 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.98it/s]
# epoch 058:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 058 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 058 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 57.97it/s]
# epoch 058 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.36it/s]
# epoch 059:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.26it/s]
# epoch 059 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 059 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.04it/s]
# epoch 059 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.04it/s]
# epoch 060:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 060 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 060 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.84it/s]
# epoch 060 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.71it/s]
# epoch 061:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.36it/s]
# epoch 061 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 061 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 59.03it/s]
# epoch 061 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.00it/s]
# epoch 062:  92%|▉| 12/13 [00:05<00:00,  2.26it/s, loss=8.806, nll_loss=8.073, pp
# epoch 062 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 062 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.58it/s]
# epoch 062 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.87it/s]
# epoch 063:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.36it/s]
# epoch 063 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 063 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 49.99it/s]
# epoch 063 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 60.12it/s]
# epoch 064:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 064 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 064 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.69it/s]
# epoch 064 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.70it/s]
# epoch 065:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.25it/s]
# epoch 065 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 065 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 58.26it/s]
# epoch 065 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.43it/s]
# epoch 066:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 066 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 066 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 54.29it/s]
# epoch 066 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.91it/s]
# epoch 067:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.29it/s]
# epoch 067 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 067 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 56.90it/s]
# epoch 067 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.65it/s]
# epoch 068:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 068 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 068 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 56.52it/s]
# epoch 068 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.19it/s]
# epoch 069:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.25it/s]
# epoch 069 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 069 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.06it/s]
# epoch 069 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 64.70it/s]
# epoch 070:  92%|▉| 12/13 [00:05<00:00,  2.21it/s, loss=8.647, nll_loss=7.889, pp
# epoch 070 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 070 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 47.32it/s]
# epoch 070 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 52.47it/s]
# epoch 071:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.34it/s]
# epoch 071 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 071 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 48.87it/s]
# epoch 071 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 55.03it/s]
# epoch 072:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 072 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 072 | valid on 'valid' subset:  47%|███▎   | 7/15 [00:00<00:00, 61.59it/s]
# epoch 072 | valid on 'valid' subset: 100%|██████| 15/15 [00:00<00:00, 71.58it/s]
# epoch 073:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 073 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 073 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.35it/s]
# epoch 073 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 60.46it/s]
# epoch 074:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.32it/s]
# epoch 074 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 074 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.93it/s]
# epoch 074 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.58it/s]
# epoch 075:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.12it/s]
# epoch 075 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 075 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.69it/s]
# epoch 075 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.46it/s]
# epoch 076:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 076 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 076 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.70it/s]
# epoch 076 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.43it/s]
# epoch 077:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 077 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 077 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 50.98it/s]
# epoch 077 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 63.85it/s]
# epoch 078:  92%|▉| 12/13 [00:05<00:00,  2.28it/s, loss=8.485, nll_loss=7.698, pp
# epoch 078 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 078 | valid on 'valid' subset:  47%|███▎   | 7/15 [00:00<00:00, 64.19it/s]
# epoch 078 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 67.15it/s]
# epoch 079:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.34it/s]
# epoch 079 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 079 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 58.81it/s]
# epoch 079 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 65.20it/s]
# epoch 080:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.26it/s]
# epoch 080 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 080 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.80it/s]
# epoch 080 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 55.12it/s]
# epoch 081:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.25it/s]
# epoch 081 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 081 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.73it/s]
# epoch 081 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 52.06it/s]
# epoch 082:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 082 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 082 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.41it/s]
# epoch 082 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 60.58it/s]
# epoch 083:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 083 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 083 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.97it/s]
# epoch 083 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.31it/s]
# epoch 084:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.33it/s]
# epoch 084 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 084 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.89it/s]
# epoch 084 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.01it/s]
# epoch 085:  92%|▉| 12/13 [00:05<00:00,  2.27it/s, loss=8.336, nll_loss=7.524, pp
# epoch 085 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 085 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.99it/s]
# epoch 085 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 64.24it/s]
# epoch 086:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 086 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 086 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.26it/s]
# epoch 086 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 63.83it/s]
# epoch 087:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 087 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 087 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 47.99it/s]
# epoch 087 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 53.04it/s]
# epoch 088:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 088 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 088 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.84it/s]
# epoch 088 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 60.21it/s]
# epoch 089:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 089 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 089 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 59.10it/s]
# epoch 089 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.13it/s]
# epoch 090:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.23it/s]
# epoch 090 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 090 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 49.97it/s]
# epoch 090 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 55.86it/s]
# epoch 091:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 091 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 091 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 54.65it/s]
# epoch 091 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.68it/s]
# epoch 092:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.34it/s]
# epoch 092 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 092 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.44it/s]
# epoch 092 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 64.43it/s]
# epoch 093:  92%|▉| 12/13 [00:05<00:00,  2.31it/s, loss=8.198, nll_loss=7.362, pp
# epoch 093 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 093 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 56.65it/s]
# epoch 093 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.00it/s]
# epoch 094:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.33it/s]
# epoch 094 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 094 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.52it/s]
# epoch 094 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.54it/s]
# epoch 095:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.33it/s]
# epoch 095 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 095 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 55.57it/s]
# epoch 095 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.97it/s]
# epoch 096:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.24it/s]
# epoch 096 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 096 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.00it/s]
# epoch 096 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.73it/s]
# epoch 097:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.32it/s]
# epoch 097 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 097 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 54.51it/s]
# epoch 097 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 66.70it/s]
# epoch 098:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.32it/s]
# epoch 098 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 098 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 49.62it/s]
# epoch 098 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 59.41it/s]
# epoch 099:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.35it/s]
# epoch 099 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 099 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 54.37it/s]
# epoch 099 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 59.93it/s]
# epoch 100:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 100 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 100 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 49.94it/s]
# epoch 100 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 59.65it/s]
# epoch 101:  92%|▉| 12/13 [00:05<00:00,  2.16it/s, loss=8.076, nll_loss=7.219, pp
# epoch 101 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 101 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 56.45it/s]
# epoch 101 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 63.90it/s]
# epoch 102:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.26it/s]
# epoch 102 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 102 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 59.45it/s]
# epoch 102 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 64.14it/s]
# epoch 103:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.33it/s]
# epoch 103 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 103 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.92it/s]
# epoch 103 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.08it/s]
# epoch 104:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.28it/s]
# epoch 104 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 104 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 54.15it/s]
# epoch 104 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.85it/s]
# epoch 105:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.31it/s]
# epoch 105 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 105 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 49.06it/s]
# epoch 105 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 53.39it/s]
# epoch 106:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.19it/s]
# epoch 106 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 106 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 46.94it/s]
# epoch 106 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 51.08it/s]
# epoch 107:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.29it/s]
# epoch 107 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 107 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 52.32it/s]
# epoch 107 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 65.54it/s]
# epoch 108:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.32it/s]
# epoch 108 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 108 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.44it/s]
# epoch 108 | valid on 'valid' subset:  93%|█████▌| 14/15 [00:00<00:00, 64.39it/s]
# epoch 109:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 109 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 109 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 57.12it/s]
# epoch 109 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.66it/s]
# epoch 110:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 110 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 110 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 51.20it/s]
# epoch 110 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.21it/s]
# epoch 111:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.22it/s]
# epoch 111 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 111 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 45.63it/s]
# epoch 111 | valid on 'valid' subset:  67%|████  | 10/15 [00:00<00:00, 46.82it/s]
# epoch 112:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.34it/s]
# epoch 112 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 112 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.28it/s]
# epoch 112 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 61.95it/s]
# epoch 113:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.24it/s]
# epoch 113 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 113 | valid on 'valid' subset:  47%|███▎   | 7/15 [00:00<00:00, 64.86it/s]
# epoch 113 | valid on 'valid' subset: 100%|██████| 15/15 [00:00<00:00, 69.99it/s]
# epoch 114:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.27it/s]
# epoch 114 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 114 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 49.22it/s]
# epoch 114 | valid on 'valid' subset:  80%|████▊ | 12/15 [00:00<00:00, 58.99it/s]
# epoch 115:  92%|█████████████████████████████▌  | 12/13 [00:05<00:00,  2.30it/s]
# epoch 115 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 115 | valid on 'valid' subset:  33%|██▎    | 5/15 [00:00<00:00, 49.57it/s]
# epoch 115 | valid on 'valid' subset:  73%|████▍ | 11/15 [00:00<00:00, 54.31it/s]
# epoch 116:  62%|████████████████████▎            | 8/13 [00:03<00:02,  2.24it/s]
# epoch 116 | valid on 'valid' subset:   0%|               | 0/15 [00:00<?, ?it/s]
# epoch 116 | valid on 'valid' subset:  40%|██▊    | 6/15 [00:00<00:00, 53.05it/s]
# epoch 116 | valid on 'valid' subset:  87%|█████▏| 13/15 [00:00<00:00, 62.07it/s]

# %%
ls trained_models
# Out:
# checkpoint106.pt  checkpoint109.pt  checkpoint112.pt  checkpoint115.pt
# checkpoint107.pt  checkpoint110.pt  checkpoint113.pt  checkpoint_best.pt
# checkpoint108.pt  checkpoint111.pt  checkpoint114.pt  checkpoint_last.pt

# %%
! python fairseq/fairseq_cli/interactive.py data-bin/trial \
  -s sat -t en \
  --distributed-world-size 1 \
  --path trained_models/checkpoint_best.pt \
  --batch-size 64 --buffer-size 2500 --beam 10 \
  --skip-invalid-size-inputs-valid-test \
  --input valid.sat > valid.en.translated
# Out:
# 2024-06-18 17:48:34.904902: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-18 17:48:34.904957: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-18 17:48:34.906648: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from sacrebleu import corpus_bleu

# Step 1: Read the translated output
translated_output_file = "valid.en.translated" 
translated_output = []
with open(translated_output_file, "r") as f:
    for line in f:
        translated_output.append(line.strip())

# Step 2: Read the reference translations
reference_file = "valid.en"  
reference_translations = []
with open(reference_file, "r") as f:
    for line in f:
        reference_translations.append(line.strip())

# Step 3: Tokenize the translated output and reference translations
tokenized_output = [tokenizer.tokenize(sentence).lower() for sentence in translated_output]
tokenized_references = [[tokenizer.tokenize(sentence).lower()] for sentence in reference_translations]

# Step 4: Compute the BLEU score
bleu_score = corpus_bleu(tokenized_output, tokenized_references)
print("BLEU score:", bleu_score.score)
# Out:
# BLEU score: 7.044404600504537
