# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sat-eng-testset/dev.sat_Olck
# /kaggle/input/sat-eng-testset/dev.eng_Latn

# %%
# !git clone https://github.com/VarunGumma/IndicTransTokenizer
# Out:
# Cloning into 'IndicTransTokenizer'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 166 (delta 14), reused 12 (delta 12), pack-reused 145
# Receiving objects: 100% (166/166), 3.87 MiB | 20.52 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
cd IndicTransTokenizer
# Out:
# /kaggle/working/IndicTransTokenizer

# %%
# !pip install --editable ./
# Out:
# Obtaining file:///kaggle/working/IndicTransTokenizer
#   Preparing metadata (setup.py) ... done
# Collecting indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library (from IndicTransTokenizer==1.0.1)
#   Cloning https://github.com/VarunGumma/indic_nlp_library to /tmp/pip-install-8pj2yx_l/indic-nlp-library-it2_d4a87ff6bed34f749e0fe466b726bf94
#   Running command git clone --filter=blob:none --quiet https://github.com/VarunGumma/indic_nlp_library /tmp/pip-install-8pj2yx_l/indic-nlp-library-it2_d4a87ff6bed34f749e0fe466b726bf94
#   Resolved https://github.com/VarunGumma/indic_nlp_library to commit 601521e05ed0ed8f2165ac317a47d186e25b6f0d
#   Preparing metadata (setup.py) ... done
# Collecting setuptools==68.2.2 (from IndicTransTokenizer==1.0.1)
#   Downloading setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from IndicTransTokenizer==1.0.1) (2.1.2+cpu)
# Collecting sacremoses (from IndicTransTokenizer==1.0.1)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from IndicTransTokenizer==1.0.1) (0.2.0)
# Requirement already satisfied: transformers>=4.39.3 in /opt/conda/lib/python3.10/site-packages (from IndicTransTokenizer==1.0.1) (4.41.2)
# Collecting sacrebleu>=2.3.1 (from IndicTransTokenizer==1.0.1)
#   Downloading sacrebleu-2.4.2-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 1.8 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu>=2.3.1->IndicTransTokenizer==1.0.1)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=2.3.1->IndicTransTokenizer==1.0.1) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=2.3.1->IndicTransTokenizer==1.0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=2.3.1->IndicTransTokenizer==1.0.1) (1.26.4)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=2.3.1->IndicTransTokenizer==1.0.1) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=2.3.1->IndicTransTokenizer==1.0.1) (5.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.3->IndicTransTokenizer==1.0.1) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.3->IndicTransTokenizer==1.0.1) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.3->IndicTransTokenizer==1.0.1) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.3->IndicTransTokenizer==1.0.1) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.3->IndicTransTokenizer==1.0.1) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.3->IndicTransTokenizer==1.0.1) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.3->IndicTransTokenizer==1.0.1) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.3->IndicTransTokenizer==1.0.1) (4.66.4)
# Collecting sphinx-argparse (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading sphinx_argparse-0.5.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: sphinx_rtd_theme in /opt/conda/lib/python3.10/site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (0.2.4)
# Collecting morfessor (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (2.2.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from sacremoses->IndicTransTokenizer==1.0.1) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from sacremoses->IndicTransTokenizer==1.0.1) (1.4.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->IndicTransTokenizer==1.0.1) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->IndicTransTokenizer==1.0.1) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->IndicTransTokenizer==1.0.1) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->IndicTransTokenizer==1.0.1) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->IndicTransTokenizer==1.0.1) (2024.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers>=4.39.3->IndicTransTokenizer==1.0.1) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->IndicTransTokenizer==1.0.1) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.39.3->IndicTransTokenizer==1.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.39.3->IndicTransTokenizer==1.0.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.39.3->IndicTransTokenizer==1.0.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.39.3->IndicTransTokenizer==1.0.1) (2024.2.2)
# Collecting sphinx>=5.1.0 (from sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading sphinx-7.4.5-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: docutils>=0.19 in /opt/conda/lib/python3.10/site-packages (from sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (0.21.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->IndicTransTokenizer==1.0.1) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (1.16.0)
# Collecting sphinxcontrib-applehelp (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl.metadata (2.4 kB)
# Collecting sphinxcontrib-qthelp (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: Pygments>=2.17 in /opt/conda/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (2.17.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /opt/conda/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /opt/conda/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (2.14.0)
# Collecting alabaster~=0.7.14 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading alabaster-0.7.16-py3-none-any.whl.metadata (2.9 kB)
# Collecting imagesize>=1.3 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting packaging>=20.0 (from transformers>=4.39.3->IndicTransTokenizer==1.0.1)
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: tomli>=2 in /opt/conda/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransTokenizer==1.0.1) (2.0.1)
# Downloading setuptools-68.2.2-py3-none-any.whl (807 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 20.8 MB/s eta 0:00:0000:01
# Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.7 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 27.0 MB/s eta 0:00:00
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading sphinx_argparse-0.5.1-py3-none-any.whl (12 kB)
# Downloading sphinx-7.4.5-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 59.6 MB/s eta 0:00:00:00:01
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 2.4 MB/s eta 0:00:00
# Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 4.6 MB/s eta 0:00:00
# Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 4.6 MB/s eta 0:00:00
# Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 6.1 MB/s eta 0:00:00
# Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 4.1 MB/s eta 0:00:00
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 4.4 MB/s eta 0:00:00
# Building wheels for collected packages: indic-nlp-library-IT2
#   Building wheel for indic-nlp-library-IT2 (setup.py) ... done
#   Created wheel for indic-nlp-library-IT2: filename=indic_nlp_library_IT2-0.0.2-py3-none-any.whl size=49558 sha256=52c9fe7da8abbba3e65ea789eafbc5476f710536cd4b1a14fcdb29baa395e5e8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gwq5gw3y/wheels/e9/72/fa/bd9f19a3f2bacb50efcaf28b7ab89fe7ca539e35b75334befc
# Successfully built indic-nlp-library-IT2
# Installing collected packages: morfessor, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, setuptools, sacremoses, portalocker, packaging, imagesize, alabaster, sphinx, sacrebleu, sphinx-argparse, indic-nlp-library-IT2, IndicTransTokenizer
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.0.3
#     Uninstalling setuptools-69.0.3:
#       Successfully uninstalled setuptools-69.0.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Running setup.py develop for IndicTransTokenizer
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.9.0 requires keras-core, which is not installed.
# keras-nlp 0.12.1 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.1 which is incompatible.
# jupyterlab 4.2.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.3 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.3.3 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed IndicTransTokenizer-1.0.1 alabaster-0.7.16 imagesize-1.4.1 indic-nlp-library-IT2-0.0.2 morfessor-2.0.6 packaging-24.1 portalocker-2.10.1 sacrebleu-2.4.2 sacremoses-0.1.1 setuptools-68.2.2 sphinx-7.4.5 sphinx-argparse-0.5.1 sphinxcontrib-applehelp-1.0.8 sphinxcontrib-devhelp-1.0.6 sphinxcontrib-htmlhelp-2.0.5 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.7 sphinxcontrib-serializinghtml-1.1.10

# %%
import json

import torch
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from IndicTransTokenizer import IndicProcessor
# Out:
# 2024-07-17 12:09:25.774617: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-17 12:09:25.774820: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-17 12:09:25.956056: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# DEVICE = "cpu"

# model_name = "ai4bharat/indictrans2-indic-en-1B"
model_name = "ai4bharat/indictrans2-indic-en-dist-200M"

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True).to(DEVICE)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# tokenization_indictrans.py:   0%|          | 0.00/8.10k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-dist-200M:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# dict.SRC.json:   0%|          | 0.00/3.39M [00:00<?, ?B/s]
# dict.TGT.json:   0%|          | 0.00/645k [00:00<?, ?B/s]
# model.SRC:   0%|          | 0.00/3.26M [00:00<?, ?B/s]
# model.TGT:   0%|          | 0.00/759k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# configuration_indictrans.py:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-dist-200M:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py:   0%|          | 0.00/79.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-dist-200M:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/914M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]

# %%
ip = IndicProcessor(inference=True)

src_lang, tgt_lang = "sat_Olck", "eng_Latn"
with open("/kaggle/input/sat-eng-testset/dev.sat_Olck", "r") as f:
    src = f.readlines()

# %%
batch_size = 16
output = []

for i in range(0, len(src), batch_size):
    batch = ip.preprocess_batch(src[i:i+batch_size], src_lang=src_lang, tgt_lang=tgt_lang)
    inputs = tokenizer(batch, truncation=True, padding="longest", return_tensors="pt",
                        return_attention_mask=True).to(DEVICE)

    with torch.no_grad():
        generated_tokens = model.generate(
            **inputs,
            use_cache=True,
            min_length=0,
            max_length=256,
            num_beams=5,
            num_return_sequences=1,
        )
        
    with tokenizer.as_target_tokenizer():
        generated_tokens = tokenizer.batch_decode(
            generated_tokens.detach().cpu().tolist(),
            skip_special_tokens=True,
            clean_up_tokenization_spaces=True,
        )
        
    translations = ip.postprocess_batch(generated_tokens, lang=tgt_lang)
    output.append(translations)
    print(translations)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3946: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ['Then, medical scientists at the Stanford University Institute of Medicine announced that they have developed a diagnostic tool that manages cells in its own unique way: a small printball that can be made with a standard ink printer.', 'Early-stage studies suggest that in low-income countries, it may account for cancer, tuberculosis, ᱮᱪ.ᱟᱭ.ᱵᱷᱤ, and malaria in patients, with breast cancer mortality being half that of poor countries.', 'At 9.30 am local time (0230 UTC), the JAS 39C Gripen crashed into the runway and exploded, causing all commercial flights to be grounded.', 'The pilot is identified as Squadron Leader Dilkurit Patawi.', 'Local media reported that the car was being towed to the airport by Sengel.', 'The 28-year-old was transferred from Sevilla to Bursa prior to the pandemic.', 'He played 49 matches for the club at Keitlan-Rajdhani, Mandalay.', 'The administration has opened the nearby White Hall at 11: 00 local time (00 UTC + 1), which faces police-enclosed access to Downing Street, the home of the prime minister.', 'After the correct 11:00 is turned off, the vehicle is turned off in the driveway at the White Hall.', 'In 11:20, police asked the protester to return to the sidewalk, stating that he needed to surrender his rights to the vehicle he was driving.', 'Crossing the LDWH with the Stend 11:29, the pass to the Green White Hall, Trifalgar Square, the Stand, and from the Kingsway to the Holburne or Raise, the Conservative Party maintains its spring form at the Greenfield Room.', 'Nadal has a Canadian Ab Khalap ham record of 7 − 2.', "He defeated Raonic's opponent in the opening round at Raka itself.", 'Nadal scored 88% in the match and won 76L on the first serve.', 'After the meeting, the King of Clay said, "I would like to congratulate you on your last return to the most beautiful land."', "Panama Papers is a portmanteau of five million copies of Panama's Kannada firm Masayya Fonseka, which was released to the press in the spring of 2016."]
# ['The investigation revealed that the wealthy jewellers in the same four banks helped to steal the Arab American dollar.', 'The Guardian reported that a team of 1,200 salespeople had been recruited from the company when they learned that Deutsche Bank was willing to pay for it.', 'There was an international outcry, many civil lawsuits, and both the leaders of the governments of Ireland and Pakistan issued Istifa.', 'Hong Kong-born Ma was educated at New York University and the Howard Law Institute and once held an American permanent resident "credit card."', 'Hesih is not allowed to run away from his home country during the elections.', 'Hasih also pointed out that the photogenic mother was more intelligent than the earth.', 'Despite these setbacks, a platform for closer ties with the mainland in Ma China was easily won over.', "Today's Player of the Day is Alex Abeykin of the Kensington Capitals.", "He had 2 goals and 2 assists in Kensington's 5 − 3 win over Atlanta Thrace.", "Ovechkin's first assist of the night was in Rocky Nicholas Backstrom's match-winning goal;", 'His second goal of the night was his 60th in the session, 1995-96 then became the first player to score 60 and above in a session, when both Jerome Jagger and Mario Lemieux reached that milestone.', 'With a net worth of $2.3 billion, Betten was ranked 190th in a 2008 poll of 400 American billionaires.', 'He graduated from the College of Engineering and Science at the University of Virginia in 1950 and was a noted philanthropist at the institution.', "Iraq's Abu Ghraib prisons remain closed during the riots.", 'The prison declined in prominence after the American military took control and suffered from internment there.', 'Pricket Junior crashed after an early stop for Fernando Alonso at the 2008 Singapore Grand Prix, knocking out the safety cars.']
# ['As soon as Alonso got into the safety car to fuel the cars ahead, he lifted the pack to win.', 'Pricket Junior was promoted after the 2009 Hungarian Grand Prix.', 'Exactly at 8: 46 am, when the entire city was about to arrive, the first jet hit its target.', 'At night, two beams of light have been made to signify Chhath Puja.', 'A five-year-old building is under construction on the site, with a transplantation centre and memorial park in the middle.', 'The PBS show has more than two dozen Emmy Awards, and its circulation is lower than that of Sesame Street and Mr. Rogers.', 'The script of each episode will focus on the theme and will be followed by multiple stories.', 'Everyone also publishes recommendations for books that children should visit in the library.', 'Janjua, ᱰᱚᱵᱽᱞᱩ.ᱮᱱ.ᱤ.ᱰᱤ said from Bufalla (home station of Lord Indradhanu) - "Indradhanu ji taught children to read,... love of music - [the day] encouraged children to read and write."', 'According to John Greenland and the public, financial difficulties and changing the scene of the educational television program are the main factors in the ending of the series.', 'Forecasters say the winds, which are 645 miles (1,040 km) across the Cape Verde islands, are lost before they reach any area.', 'Freud has a wind speed of 105 m / h (165 km / h) at Halley and is moving east-west.', 'Following satellite imagery, Fred is the largest tropical cyclone ever recorded and the third-largest hurricane ever recorded in front of 35 ° W.', 'On April 24, 1759, the British signed the Treaty of Dublin, Ireland, for the Settled James Cemetery, dating back 9,000 years.', 'More than 250 years ago, the United States accounted for about 10 billion euros (US $14.7 billion) a year in gold mining business.', 'John Reid, the co-driver for the A1GP New Zealand team, is making a new debut today with a 48-year-old car over Auckland Bridge.']
# ["The Honoree Red introduced New Zealand's A1GP car, the Black Beauty Co., seven times over the bridge at a speed of 160 km / h.", "New Zealand's A.J. Lullis could only map his bag with a bag raider or see how fast the Black Beauty was moving, with the police measuring his bag at 160 km / h.", 'In the last 3 months, 80 registrars have been released from the Central Booking Facility, who have been released without prior education.', 'In January this year, the Justice Glenn issued a three-and-a-half ᱴᱷᱟ.ᱣᱠᱟ.Continue reading, which would have issued a 24-hour-to-a-half relief benefit for people in need, which would have been unenforceable by a court order.', "The commissioner sets the bell, if given, and the arresting officer trains them ahead of the charge. Those charges go to the state's tax system, which tracks the case.", 'The law also specifies the date of the right of the victim to be treated with the drug.', 'Peter Costello, Australian politician and leader of the Liberal Party, gave his resignation to Prime Minister John Howard after the overthrow of the Permian government in Australia.', 'Mr. Costell said that while the Permafrost plant was to be used for economic development, it was to be used by Australia.', 'If it is a commercial venture, it should be done in the middle. Sri Costell says that there is no such thing as a legal dispute with the authorities of Permacruz.', 'According to Tussauds, "The police were on the receiving end of a few top-level hits, fearing that a full-blown war of attrition might break out again."', "The police stated that Law Pickle had the upper hand because he was the right-hand man in the operation and that his superiority gave him the respect of his father's family as he followed a policy of keeping the operation as low as possible along with tightening his guard.", 'These owners would have been blocked by the administration when they ended the Rina-led campaign against the regime, which in 1992 claimed the lives of Mafia defendants Giovanni Falcon and Paula Varsalina. "', "Apple's CEO Jobs went to Manchester and unbanned the device, taking the e-phone out of his pocket.", 'During his 2-hour speech, he said that "Today Apple starts making phones again, today we are going to make history."', 'In this genre, the main character is the great Rau Kathilik, and the Rau Kathilik character brings the same rhythmic vibes from the past.', 'The National Congress of Bengal had 10 years of deliberations on legalisation, and the Nakan Nagrik marriage took place in the Kebar Riau village.']
# ['The original bill was directed by former mayor of Sao Paulo, Marta Supplici. The motion, which was introduced after the election, is now in the hands of Roberto Jefferson.', 'Activists hope to gather 1.2 million signatures to face the National Congress this month.', 'After this decision was made, many families are seeking assistance with evictions, and on March 20, the East Bay Community Law and Order Center launched an initiative for home evictions.', "Many family members concerned about what's wrong with the cashiers talking to each other are concerned that OHA's Carlian Johnson has depleted their security deposit and left the market.", 'Since the owners of Lockwood Gardens believe that there are another 40 or so families waiting to receive evictions, they have learned that OHA police may be looking into individual housing properties in Oakland that have received housing scams.', "Mowie's white show at the Memorial Stadium, which had a crowd of 9,000 people, was held to ask for forgiveness from the public.", "White management, ᱮᱪ.ᱠᱮ. management, ᱟᱭᱤ.ᱮᱱ.ᱥᱤ, gave no reason for the show's cancellation on September 20, but cited logistical reasons for the second announcement.", 'The famous Greek lairmen Sachis Kahnigala and Georg Niklakapaulos were imprisoned in the Hellenistic prison at Karaidolus for receiving bribes in craft and carpentry.', 'As a result, in recent years, the Greek legal community has had a major boom in publishing the illegal work of judges, lawyers, solicitors, and attorneys.', 'A week earlier, after journalist Max Trinetaphylopoulis published the use in Alpha TV\'s popular TV show "Jowgal," the journalist and lawyer, Patras Mantervals, had his bloodline aborted due to grafts and cuts.', 'In addition, the great judge Avangelsus Callurius was sentenced to imprisonment and the degenerate Das Scythia.', "Robert's submission was denied on the grounds that his statement about when life would begin would be unwarranted to tip the bar in the T-Smith case, an important question during the trial in the corruption scandal.", 'That is, he denied his earlier claims that R Banum Veed was "not in good health," which would have empowered the Supreme Court to uphold the trial.', 'He made it clear that he believed in the absolute right to self-determination in which justice was expected.', 'Maruchider was removed from the top of the staircase, the second being six steps from Nusa.', 'Both sides will meet in the semi-finals, which will be won by the winner of the Nusa 11L.']
# ['Maruchider again defeated Kabulachar in the opening final.', 'Hyasperonychus is a genus in the family Elizapitheae, the paternal half-brother of Dromesauridae and Velasiraptor.', 'It is believed that birds of prey, such as the egret, red-blooded bird, used to go straight to the dwarves in search of vesicryptors.', 'The second search was the larger one, the Hyasperanichus eponym, which means "Western search."', "Unlike Kukkar Baraf, Charam was busy trying to save Sajan's life.", 'The report suggests that the situation will not improve for some time in the second week.', 'As a matter of principle, the size and shape of the pack barf has been the worst for sealers in the last 15 years.', "Today, rumours spread in the Red Lake community as Jeff Bezos's nephew and three of the eight suspects were arrested and arrested for the March 21 shooting incident.", 'The court ruled that there was nothing more to be said about the arrest.', 'Hallelujah news outlet Minneapolis Star-Tribune reported that the chairman of Red Lake Triball, Floyd Jourden, was Louis Jourden at the age of 16.', 'At this time, it is not known what charges will be brought or which authorities will be handled by the man, but juvenile proceedings have been initiated in federal court.', 'Lodin also stated that the authorities had decided to ban the ban in order to save Afghans another election expense and security fears.', 'Deputies have stated that they have received the same number of grants in the Afghan constitution to make the ban unnecessary.', 'This is in contrast to the earlier report, which stated that the ban would be against the constitution.', 'The aircraft continues to fly towards Irkutsk and is operated by the Interior Forces.', 'An inquiry has been set up to investigate.']
# ['Since the 1970s, the Il-76 has been a staple of the Russian military, and recently last month there was a serious incident.', 'On 7 October, a pilot escaped unharmed at the Taqf, after which Russia scrambled Il-76s to intercept him.', 'An 800-mile stretch of the Trans-Alaska pipeline was closed after thousands of barrels of oil spilled near Fairbanks, Alaska.', 'After a routine fry command check, the power supply valve is opened and the fuel tank is turned on near Fort Charlie Ffm Station 9.', 'The opening of the valve releases pressure into the system and flows from the oil pad into a tank that holds 55,000 barrels (2.3 million gallons).', 'On Wednesday morning, the tank vents are still leaking due to the spread of the virus in the tank enclosure.', 'The second container under the tank, which holds 104,500 barrels, is still not fully filled.', 'Live broadcast was the first in television history to support major Iranian sources as to what the impact of the increase would be.', 'This has led to economic sanctions and restrictions on the sale of Iranian crude oil, with Iranian oil producing 80 per cent of the foreign income.', 'In the latest global news, OPEC says its crude oil output fell to a two-decade low of 2.8 million barrels a day.', 'The country\'s supreme leader, Ayatollah Ali Khamenei, ordered the oil to be released from what was known as the "Islamic Jallam" before Iran\'s Islamic Revolution in 1979 and from which country.', "When the rain capsules hit the Earth's crust and hit the atmosphere for 5 hours (front time), it could rain very lightly in California, Oregon, New York, and Hawaii.", 'Capsules are found in the number of capsules sold per year.', 'The capsule traveled 12.8 km and 8 mi in a single-legged bag, travelling from San Francisco to Los Angeles in a matter of minutes.', 'The Apple X command set a new all-time record for the fastest international flight to land in the START world, breaking the first record set in May 1969.', 'Stardust\'s manager, Tom Docsbury, said, "New York is open year-round to travel to the California coast and travel from California to central Oregon and New York and Ohio."']
# ["Mr. Rudd's definitive agreement on climate change is the United States Constitution, which does not guarantee the existence of any natural resources in the Americas.", "Australia's first colonial government refused to support Kyoto on the grounds that the coal mine's safety caused the economy to decline, which was not the case with developing countries such as China and China.", 'It has the largest population in the history of eBay.', 'The company has decided to bring the software to its Cowboy store and name the place where Skype has a strong presence.', 'Scientists have biologically identified Enceladus as a possible source of the dark and snowy color of the sun.', 'Enceladus is the most reflective light in the solar system, emitting up to 90 percent of the light of the day.', 'The English publisher Konomi said in a recent news report that Six Days games are being sold in Fallujah.', 'There are references to the Second Battle of Fallujah, which was an engagement between the American and Iraqi armies.', "The ACME also found that once the video was streamed on the Internet, Big Brother would not have violated the Online Marketing Scholarship Act because the media would not have been hosted on Big Brother's website.", 'Publicity services are available as a regular part of the inter-jala samagri, but in order for the inter-jala samagri to be celebrated, it must be physically located in the sarovar.', 'Kenya\'s ruling elite continues to worry that the "Samalian pantheon" is planning to launch bomb attacks on Kenya and Ethiopia on its own.', 'The Americans say he has been exposed to an unknown source who is known to have carried out attacks on himself, particularly in Ethiopia and Kenya, in order to evade "pre-emptive actions."', 'Shortly after The Daily Show and The Culbert Report, Heck and Johnson planned to publish a documentary - which would parody smear and smear reporting - in which he was a reporter in the 1988 year ᱭᱩ.ᱰᱚᱵᱽᱞᱩ.', "Since his founding, Payz has created real-world news products, including print magazine Sanskriti, the website that launched the 5,000,000 editor's blog in October, Facebook Business, 24-hour news, podcasts, and the instant-release Global Atlas.", "Al Garr and General Tim Franks are literally walking away from his cousin's headlines (when he says he and Tipper's 2000th electronics college were the worst things he's ever done in his life).", 'Many of their writers are influencers from the John Stewart and Stephen Colbert news parody shows.']
# ['The events of the book are also divided into the recent events of Bookhurst City, which is the capital of Rajasthan, and another event in the form of Rangin Managar.', 'New Delhi has become the first city in the country to conduct a global male-to-male competition from December to February this year.', "Today's announcement also augmented the government's commitment to increased corruption in March of this year.", 'Another 300 carriages can be brought and sent and 1,300 more can be sent to clear the area.', 'Los Angeles Police Department spokesman Christopher Garcia said the suspect was acting to harass the male offender without warning.', 'He was used by Kirpal Rai, who did not play with a high level of concentration, was calm and composed with a sense of calm, but was able to change the "O" to read the letter "e."', 'The lilac fever occurs if it exceeds the normal concentration of the carcinogen, which is a naturally occurring parasite.', 'The traditional karaoke model can be modified to make the situation more stable, thus increasing the number of karaoke trees.', 'Algae release a new neurotoxin that is nerve-wracking for both humans and fish.', 'Fish are often killed by poisonous concentrations in the water.', 'People can also become infected if they are carried by the storm-affected waterways mixed with wind and snow.', 'At its peak, the powerful Cyclonic Storm Gonu, known colloquially as the Sun with a bag of gunpowder, reached a maximum sustained wind speed of 240 km / h (149 mph).', 'Soon after today, the wind was 83 km / h, and it was expected to be low.', 'On Wednesday, the National Basketball Association (NBA) of the United States of America auctioned its own basketball set due to concerns regarding COVID-19.', 'After the NBA trial, the player was tested positive for the COVID-19 virus.', 'In the context of neologism, this means that the division is far ahead of the comparision of relativism by physicality.']
# ['"This means that everything will be back," said Behren Asfa, a writer and associate professor at the Rift Valley Research Service in Ethiopia.', 'Due to its widespread use in the United States, AOL has been able to shift and grow the IM market with its technology.', 'With this method, the disorder can be eliminated.', "Yahoo! interacts with AOL's customer base, including user base and Microsoft services.", 'Northern Rock Bank was nationalized in 2008 after the company was informed that it had received financial assistance from the government.', 'Northern Rock continues to need help due to his exposure during the 2007 Supreme Court Morgan Crisis.', 'Sir Richard Branson annulled an investigation of the bank following the nationalization of the Virgin Islands Bank.', 'In 2010, at the time of nationalization, the present-day High Street Bank was separated from the Northern Rock Public Sector Bank, "Northern Rock (Asset Management)."', 'Berzin has just bought the "good bank" of unknown rock - not the company that owns it.', 'It is believed that this is the fifth time in history that people have seen what are the chemically confirmed divine objects burning in the earth.', 'Of the 24,000 known lakapindas that have fallen to the earth, only 34 are known to be truly divine.', 'The rock is 15 feet in diameter and is responsible for the foundation.', 'That rock, which is rarely found in the world, is being sold for between US $11,000 and US $22,000 a year, ten times the price of gold.', "After the race, Kasseksky won the Divers'Championship with 2,250 points.", 'After seven points, Johnson finished second with 2,243 points.', 'England are five points behind, but five ahead of England. Kane and Brooks are fourth and fifth respectively with 2,220 and 2,207 points, respectively.']
# ["There are four races left in the season, with top ten spots up for grabs for the Steward, Garden, Cancethe, and Harvik Drivers'Championships.", 'The American Navy also said it was investigating the incident.', '"The chal is now working on the most comprehensive design of the ship," said Renuka Navin.', 'An Avenger Class Mines counter map ship, the ship was sailing through Puerto Princesa in celebration.', 'It was delivered to the Americans in seven fleets and is located in the city of Nagasaki in Japan.', 'Mumbai was hit by the cyclone 26, which reached Mumbai in 2008, accompanied by waves of tornadoes, small arms raids, and landslides at several places, including Chhatrapati Shivaji Terminus railway station and the famous Taj Mahal Hotel.', 'Scouting and reporting of David Headley helped determine the 10 terrorist activities of the Pakistani militant group Lashkar-e-Taiba.', 'The conflict further strained relations between India and Pakistan.', 'Along with the officers, they assured the Texans that they would work to protect the people.', '"There are places around the world that are well-prepared to address this issue of corruption," Père said in particular.', 'The Governor also stated, "Today, some institutions have identified children as active cases of the disease."', 'He said, "This mummy is red. Stay calm, your mommy is doing exactly what she\'s supposed to be doing."', "If true, this term completes the term of the year of the Prophet's visit to Iran.", 'After seabed mapping, the use of Malbe RV was compared.', 'One of the youngest people in the village, Chini has reportedly started his quest for the name of Musa with his multi-faceted penchant for river rafting, and in a fit of desperation.', 'He won the admiration of Critis during his time in Atlanta and became known as the new educationist.']
# ['In 2009, he was recognized with the National Supremacy Hunt of the Year Award.', 'At the time of the award, I noticed a huge improvement in the test scores at the institute in Atlanta.', 'Sometime later, the Atlanta Journal of Medicine published a report that looked at the effectiveness of the experiment.', "Reports suggest that the investigation was highly skewed, and it was found that there were problems with the institution's internal image, but action was not taken immediately.", 'Subrata then states that the syllabus will be updated with the hall, along with 34 other teaching officers who will be suspended in 2013.', 'The Irish government has appealed to Saudi Arabia to restore order.', 'A government spokesperson said that it is now too big to see both the body of the individual and the criminal remedy, "that the law should be implemented immediately."', 'The Minister of Health has been involved in the treatment of patients with non-communicable diseases and has now been involved in the treatment of patients with non-communicable diseases since the beginning of the pandemic.', 'On the same day, he took a pre-season break from the pre-match matches in Guwahati, Italy. He took a break at the team hotel ahead of the match on Saturday.', 'He took rest in the hotel on the eve of the match in the first match of the tournament on Saturday.', 'The Bus Six Flags were on their way to Louis-In-Louis, and there was a large white sales crowd for the Missouri Flags.', 'According to eyewitnesses, the car turned in front of him as he was crossing the green at 1: 15 p.m.', "By the 9th century, Morocco's attention was 70 miles away from the Chinese province of Fujian.", 'The storm is expected to make landfall in the early hours of the day from the Chinese side.', 'At 90 (Fahrenheit) -degrees, water is given to the suspended passengers.', 'Fire Captain Scott said, "This was Santa Clara\'s hottest summer in 90 years.']
# ['It\'s not uncommon to be stuck in the roller coaster for a long time, to say the least, and it takes an hour before the first person to get out of the car. "', 'A seven-time Formula 1 champion, Chumachar, who took over in 2006, will replace the outgoing Felipe Massey.', 'He suffered a concussion in the head during the 2009 Hungarian Grand Prix.', 'Masha will sit until the end of the 2009 season.', 'Foreign Minister Rodrigo Duterte has said he would not rule out taking any tests due to the virus.', 'The situation is good when he has been on leave for a long time.', 'Apart from fever and nerve pain, I feel better and I can do my job with telecommuting.', 'Arias said, "I hope I can finish all my work.', 'Felicia, who is listed as a Category 4 hurricane on the Saffir-Simpson Hurricane Scale, fell before making a major landfall on Tuesday.', 'Many icebergs are flooded due to its impact, but there are currently no reports of any damage.', 'Rainwater falling at a rate of 6.34 ° C in a single death on Ahu is described as "beneficial."', 'With some water, the water remains stagnant.', 'An attempt was made to fly a Twin Otter Airlines PNG aircraft, CG4684, near Hala Kokoda, but it was shot down on the same day.', 'The new flight was lost before it could take off for the second time a decade ago.', 'The scene of the shooting was found today and was so accessible that two policemen were called in to speak to the survivors.', 'The incident took place in the same manner as the ill-fated landing.']
# ['According to the reporter, the explosion occurred due to the explosion of the Macbeth Bridge.', 'An officer of the gas company was reporting there, as a nearby person had reported it.', 'This was when the authorities blew up the Satarena airport.', 'No major injuries were found, but five people were treated for injuries.', 'There is no one inside the kitty. ᱛᱟᱦᱮ.ᱞᱮᱱᱟ', "At the same time, let's say 100 people in that ᱤᱞᱟ.ᱠᱟ number are called ᱤᱞᱟ.ᱠᱟ.", 'Both golf and rugby are to be returned with the Olympic Games.', 'Today, the International Olympic Committee at the Exchequer in Berlin has approved the sport of the sea - i.e., rugby and golf from the other five sports considered at the Olympics, in particular rugby union.', 'Squash, karate, and roller sports became Olympic sports, as well as attempts to enter baseball and softball, which were eliminated from the Olympic Games in 2005.', 'Copenhagen is still to be voted into office by the IOC in early October.', "All women's ranks did not support Samir.", 'Amir Khan, who won the 2004 Olympic Rajak Trophy, said, "I strongly feel that women should not fight."', 'In addition to his supporters, he has stated that he will be in London supporting the British delegation at the 2012 Olympics.', 'Markardama was held at Birmingham Crown Court and concluded on 3 August.', 'His spokesman, who was arrested in connection with the incident, said he had not been attacked and claimed that a group of three people had used water cannons to prevent the bombs from exploding.', 'Malleck was also charged with obstruction of justice.']
# ['The judge tells Black that this "benevolent aneurysm" sends him to jail.', 'Dark energy is the invisible energy in the atmosphere that is exerted in the atmosphere.', 'This lineage is known to have been the cause of the outbreak in the Vistara region of Jharkhand.', "The residents were asked to divide the month into two parts, which was done by the Labet Scraps manager, who saw the month's slow-moving pace as a result of the SPAST app.", 'This sign is available throughout the month and there is little or no vaccination, indicating that there was some degree of biological damage to the sign.', 'This theory divides the claim into that the month is spent in full biological activity.', 'He drove a group of three-wheelers away from the crowd.', 'When a bomb is detonated, the hostages are arrested after being ejected from the blast.', 'His name is still unknown to the Sikhs, but they do know that he is a member of the Uyghur tribe.', 'Nadia, who was born on 17 September 2007, to Caesarean section at a maternity clinic in Alex, Russia, weighed 17 pounds 1 ounce.', 'â €œWe were all shocked, â €he said.', 'When asked what his father had to say, he said, "He didn\'t say anything - he just kept on standing and complaining."', 'It is used as a water source, it is as fresh as water.', "This means that if you stop at the beach, you'll see less of all the cork and yarn underneath.", 'However, only one ten-pointed body exhibits greater dynamism than Titan, and its name is Earth, "Stauffen added.', "The issue first came to light when two-and-a-half dozen local residents complained to the post office that they had not received the customary and regular New Year's cards."]
# ["Halla asked for his apology from the press and media, after learning that the man was hiding 429 New Year's cards and 600 postal papers that had not been delivered to his target.", "In the mean month, the orbiter Chandrayaan-1 released its Moon Impact Probe (MEP), which slammed into the Moon's surface at a velocity of 1.50 km (3,000 mi) per second, crashing into the Moon's near-Earth orbit with rapidity.", 'In addition to the three important scientific instruments, there was also the National Chair of Monthly Research, which was all-encompassing.', 'â €œThank you for being such a generous member,â €\x9d said Sriprakash at a press conference.', "People may not believe it, but I don't believe it.", 'I am glad to know that there are people who support me.', 'Ever since Pakistani independence from British rule in 1947, the Pakistani president has appointed "political agents" to run the FATA, which runs the entire parliamentary administration in the region.', 'The new agent is responsible for providing government and judicial services under Article 247 of the Constitution of Pakistan.', 'In the Islamic holy city of Mecca, a hostel is open at 10 am IST.', 'There were many pilgrims in the palace who came to visit the holy city at the exact time of Hajj.', "The hostel's staff is mostly drawn from the Nagrik people of the United Arab Emirates.", 'The death toll is less than or equal to 15, although the number could rise.', 'Leonov, also known as "Cosmonaut L11," was part of the original team of cosmonauts in Singapore.', 'On March 18, 1965, they were alone for a little more than twelve minutes in front of a public utility vehicle (EV), and not a "spacewalk," which was interconnected.', 'He received the highest award for his work, "Satyajit Ray\'s Hero," by the Satyajit Sangam.', 'Ten years ago, he announced his decision to split the membership of the private Suez Mission, in response to the new idea that the escape of the Antilles was over.']
# ['"There is no secret information to give new clues that an attack is possible," they said.', 'However, reducing Khatra\'s ranks to Gamvir does not mean that all the threats have been eliminated. "', "However, due to concerns about the integrity of the executive branch, the Maryland Transportation Authority broke with the FBI's request.", 'Hump trucks were used to block the entrance to the tube, and 80 policemen were employed to guide the motorist to the wheel.', 'There are no reports of heavy traffic on the Beltway, the other road in the city.', 'Nigeria has previously stated that it plans to go to the Sikh organization to prepare for the sea at AFSCTA.', "The AU's trade and tourism authority, Albert Moochanga, has warned that the Bay of Bengal is on the verge of collapse.", 'The Commissioner said, "We have so far agreed on a comprehensive basic and tariff-concession law, and what we have in place will have to start on 1st January 2020."', 'Despite having the first gyroscope in the Interstations mission, the station retained its focus until the end of the spacewalk.', 'Chiau and Satyaparam suggest fighting with ultra-high-altitude resistance thrusters up to the defensive end.', 'The board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors of the board of directors.', 'The lawsuit was filed in Virginia because the new primary internet service provider is home to ALL, the company that took the lawsuit.', 'It was the first time users shared email in mailboxes without any hassle, until they gained a deep belief in the use of encryption in 2003 to prevent spam.', 'He joined Manchester City after 21 years in January 2017 for a reported fee of €27 million from English club Palmeiras.', 'Since then, he has played 53 matches for the club in all competitions, scoring 24 goals.', 'D. Lee also mentioned the request that the Turkic tribesmen were now infected with A (H5N1) abiotic influenza.']
# ['He said that some studies have shown that it is less likely to be fatal in the long run due to the spread of the virus.', 'With this in mind, it is thought that if the flu symptoms are mild, Raghu can continue to treat most of his patients throughout the day.', 'Leslie Ann, co-founder of the Kamen Foundation, said that the new law will make it legal and non-discriminatory for organizations to take action.', "Kamen's policy is to keep the plan family informed as the plan family spends money and reports their money to the messenger Clip Stearns.", 'Stearns argues for the need to address the issue of housing and the economic crisis in the context of poverty and poverty.', 'The former mayor of Massachusetts, Ramni Bale, won the first round of the Florida Republican National Convention with a margin of over 46 percent.', 'Former U.S. Speaker of the House Nadia Gingluo finished second with 32 points.', 'A win-win state, Florida, awarded five delegates to Ramney, who went ahead of the race to win the nomination for the Republican nomination.', 'Western experts have suggested that as many as 100,000 people came to cities such as Berlin, Cologne, Hamburg, and Hanover.', 'In Berlin, the police arrested 6,500 people.', 'Floods have also occurred in Sofia in Bulgaria, Vilnius in Lithuania, Valletta in Malta, Tallinn in Estonia, and Edinburgh and Glasgow in Scotland.', "In London, the copyright holder's office was raided in 200 BC.", 'Last month, a major forest fire broke out in Polatlı when the ACTA was signed in that country, due to which the Polatlı government has now decided to cancel the contract.', 'Two ACTs, Lativa and Slovakia, were delayed until the end of the season.', 'The Royal Society for the Animal Liberation of the Prevention of Cruelty to Animals (RSPCA) has mandated the installation of CCTV cameras in all Australian abattoirs.', "RSPCE's South Wales Chief Inspector David O'Shaney told ABC that Australia's abattoirs and sightings should be commonplace."]
# ['"CCTV sends strong signals for the well-being of people working with mosquitoes."', "The Zoological Survey of India states that the National Earthquake Map shows no Earthquake in the world in a week's time.", 'The Icelandic Meteorological Office reported no aftershocks in the area after 48 hours.', 'On 10 March, tremors were felt in the northeast of the caldera due to a change in the intensity of the cyclonic circulation.', 'It was reported that the harem was not connected to any meteorological activity at the base of the hill.', 'The notes point to a force that is really like an explosion.', 'When the Luna broke, it contained 120-160 cubic metres of oil and most of the wind and winds were driven by this brake.', 'The helicopter crew was rescued and only one casualty was reported.', 'The 100-kilometre ship was waiting in line to take her fertilizer to Harare, Maine, and Willow, fearing that Vessel would be shot down by the U.S. Navy.', 'Amandeep Singh, who moved into both houses in 2011, is married.', 'A change was made in this assembly session but the second sentence was removed by the first amendment and the new form was superseded by the new senate.', 'The contradiction of the second sentence, which is the same as that of the Council of Ministers, opens the door to the Council of Ministers.', 'After the process, HZR-3 was replaced by the newly elected Assembly in 2015 and 2016 to remain in the process.', "Out of the woods, Vautier's coach saw for himself in a 1973 Hunger Strike political censorship.", 'The rule of law was changed when he was 15 years old, and during World War II, he became involved in the war in Syria.', 'She self-published a book in 1998.']
# ['In the 1960s, he moved to the newly formed Algeria to study film directing.', 'Judoka Hitoshi Saito of Japan, winner of two gold medals, died at 54.', 'The cause of the death was described by the intrahepatic bike doctor as cancer.', 'He died in Osaka on Tuesday.', 'As well as being a mother Olympic and World Pumpkin, Seto was the chairperson of the All-Japan Judo Federation Research Committee at the time of her death.', 'Last year, at least 100 people would have gathered in the party to celebrate the first Saligirah of a married couple.', 'The formal anniversary event was on the last date, i.e.', 'He got married in Texas a year before the wedding and moved to Buffalo to study with friends and relatives.', "Buffalo's 30-year-old husband, Goki Marao, was one of four people killed, but nothing happened to his family.", "Karna is a well-known but vivacious Punjabi teacher, educated by the Royal School of Education and the King's College, who employs 9,000 students at the peak of his career.", 'In his notes, he used the same words that some of his parents used to celebrate, and he used to use the word in the background.', 'Mandarin Shiksha asked him to leave and posted a big-ticket video on the bus, falsely claiming that the main character was a teacher.', 'He had already been slapped with a copper-plated sword, but he was not slapped.', 'One of the mother students said that she was fond of kite-flying in class, what the dating council did at the knots, and that she was like a "friend" to the students.', 'During the last three decades, after the establishment of a princely state in Admiralty Tower, a new temple complex was built in China.', 'The first economic reform took place under the leadership of Deng Xiaoping.']
# ["Since then, China's economy has rebounded.", "For the first time, last year, China overtook Germany as the world's top driver of automobiles and the United States as the top destination for this export.", "China's GDP is larger than that of the United States, except for two decats.", 'Tropical Storm Danielle, the fourth major hurricane of the 2010 pre-Hyphoon season, formed in the eastern hemisphere.', 'Located 3,000 miles from Miami, Florida, the maximum sustained wind speed is 40 mph (64 kph).', 'Scientists at the National Weather Service say Danielle will emerge stronger in a storm as soon as Wednesday.', 'Because the storm is located far from landfill, its impact in the contiguous states of the Americas and the Caribbean is unlikely.', 'Born in Zagreb, the capital of Croatia, Bobek is best known for his friendship with Pigeon Belgrade.', 'He joined them in 1945 and was born in 1958.', 'During his time with the team, he scored 408 goals in 468 appearances.', 'Apart from Bobeck, no one else has been able to score as many matches and goals for the club.', 'In 1995, he was voted the best player in the history of football.', 'The start of the celebrations began with the performance of the internationally renowned chess player Sark du Sile.', 'This was followed by the Istanbul State Symphony Orchestra, January White, and singers Fathika Ekak and Muslim Gays.', 'Later, he went on to take a walk along the river.', "Tarki's Diva Aixu is performed with Italian tenor Alessandro Safina and Greek singer Herix Alexia."]
# ['For the release of the film, Tharki\'s dance drama Doll of Antalya features the action of "Trio."', 'The 13-year-old bicycle race putter Lange died after being involved in a traffic accident at Indiana Mile Speedway.', 'Despite being in his own eyes, Lenz is distracted by his bike, and the socialite strangles him to death.', 'He was seen by the staff of the Tirant law-tank and taken to a nearby hospital where he died.', 'Jaiswal did not do anything in the incident.', 'According to the World Economic Forum, Zapatero declared that "the global economy is the economic division of the world, the economy is the largest division of the world."', 'We have a one-year financial crisis in the country, which has been the worst for two months, and the financial markets in my area are recovering. "', 'In the past, Naked News has claimed to have expanded its international national language reach to include news with a new publisher called Naked News.', 'Already, reporting in English and Japanese, audio-visual television, audio-visual, and mobile devices are being developed in Spanish, Italian, and Korean.', "I don't have anything to worry about, hey, I see a lot of stuff, because people are breaking windows to get out.", 'The people were blindfolded, but the roof remained unbroken.', 'The eyeballs later broke, and they came out of the window, "said the survivor, Francescale.', 'When hydrogen permafrost can be mixed (mixed) together to make heavier materials, only light and light can come out of the wire.', 'Scientists are working to build a reactor that can produce the same amount of power.', 'There are many problems with this solution and it can take many years before a solution can be developed.', 'Due to the surface tension, the steel needle is floating on the water.']
# ['Surface erosion is significant because the surface has a second-rate excess load compared to the water core.', "The core of the water creates an invisible screen on the water's surface that allows needle-like objects to pass over the water.", 'In a modern ice skate, the middle of the blade is covered with a ball of ice along the edge of the drill, giving a sense of the edge of the ice even when tilted.', 'Because the bottom edge of the blade is prone to short rotations, the jelka blade is inclined to one side and not the other, cutting along the edge of the ice shear.', 'This causes the skater to turn. If the skater is leaning towards the left, the skater is turning the right hand, if the skater is leaning towards the left hand, the skater is turning the left hand.', 'In order to return to its former strength, it is necessary to increase from the excess strength obtained from the kernel.', 'They draw the "photon" by drawing the power of the reddish-brown corner of the arrow.', 'Biological innovations are called "improved radiation generation" because energy is released from the radiation, which causes the radiation of the radiation to evaporate, and the radiation of a product is called radiation.', 'The preceding table shows the parameters of photovoltaic power, since the image contains more particles than the photovoltaic image.', 'The image remains the same as the material from which the image is made.', 'Several hours before the operation, the bulb is sprayed with filament and the arsal tube does not work.', 'The light bulb needs to be replaced with another light bulb. The bulb needs to be replaced with a light bulb.', 'Initially, the switch must be closed or the cable must be disconnected in order to stop the leakage.', 'This is because the person running in the socket who is sitting on the side of the ball that is being hit, may be able to hit the ball if you hit the outside of the socket and the outside of the non-ball, but it still stays on the socket as normal.', 'The major organ of the circulatory system is the blood vessel, which carries the fluid.', 'The tube through which blood exits the blood vessel is called the arteri, and the tube through which blood enters the blood vessel is called the vein. The shortest tube is called the capillaries.']
# ['The teeth of a trichyratops are not only leafy but also have many roots and roots.', 'Some scholars suggest that Trichyratops fed on cyciatus, a type of plant that had a deficiency in gerataceous.', 'The plant looks like a small banyan tree with a thin, foliage-like trunk.', 'A triseratops trunk is able to separate the anthers from the food with its rigid trunk.', 'Others argue that the plant is very frugivorous, so it is not as easy as eating dinosaurs, as today algae and other dinosaur-like insects (dinosaur ants) can eat citrus fruits or berries.', 'How does the gravity of the loo affect me? If you stand on the edge of the loo, your weight will decrease relative to the ground.', 'A person who weighs 200 pounds (90 kg) on the ground weighs 36 pounds (16 kg).', 'There is no festival of the month of Diwali as if you are standing on the ground. The month of Diwali is made up entirely of gas and plasma.', 'The distance from the center of the month of Dhanteras is less than normal.', 'The outer part of the eye that is visible when you look at the moon is called the photosphere, which means "flame of light."', 'Three thousand years later, in 1610, Galileo Galilei, a Greek astrophysicist, used a telescope to view small objects, such as moonlight.', "There are reasons why only Sukra (of the month) governs the lunar month. The belief of Copernicus in Sukra's charana is supported by the fact that the sun is moving in the same direction as the lunar month.", 'A few more years later, in 1639, a Gujarati scholar named Khagalshastri saw the paragama of Sukra.', 'After a repeat victory over the Danelaw, he felt calm for a long time - I.I.', 'However, in 991, the Athleterad became the subject of a Viking fleet, which was cut short by something after a storm in the dungeon.', 'The ship was launched by Olaf Tryggavason of Norway, who hoped to return to his country from Denmark.']
# ...
# ['These requirements depend on which countries the national is visiting or the purpose of the trip.', "One of the strong points of North Carolina's solution is that it has a wide variety of options for consumers.", "Residents in other areas often find it a practical reason to visit, such as shopping malls, and to easily have fun with children from the city's neighborhoods.", 'In the next 20 years, the children in the Uptown Salon are undergoing a series of tests to determine the appropriate dosage.', 'Taxis are not often preferred by salaried customers, but they may be somewhat cheaper in some situations.', 'Searches are required if there are more than 2 indicators, so this indicator may be overpriced.', 'Antarctica is the coldest place on Earth and is surrounded by the Atlantic Ocean.', 'There is a need for physical fitness, which can only be done in Niron-Ambar-Fari, and is generally limited to the peninsula, the islands, and the Lakshadweep Sea.', 'Some thousands of workers live in the surrounding five-storey buildings, mostly in those areas; there are fewer in winter.', 'Antarctica is a tropical landmass with an interior 2-3 ᱠᱤ.ᱢᱤ arrays.', 'For trekking or reaching Dhruv, one has to travel by a real-world flight, which is a big deal.', 'There is a 1,600 km route from McMurdo Station to Dhruv on the South Dhruv Treus (or Rass Sea).', 'It is the frozen ice that has fallen and is identified in the zone. This can only be identified by special tanks, which are equipped with fuel and electricity.', 'It is not uncommon for the pagandhi that flows into the lake to take a long detour around the Transarctic Mountains.', 'The main causes of accidents in winter are falling vehicles, footpaths (footpaths), and in particular, stops.', "At the very least, you'll need to wear shoes with the necessary soles. Warm shoes will often wear out in the snow and ice, even in cold weather."]
# ['The material must be thick, 5 millimeters (1 ⁄ 5 inch) or larger, and the material must be soft enough to withstand cold temperatures.', 'Some devices have an extended add-on feature for extended wear and tear, which can be used for extended wear, ED or EDI, and locks.', 'The ED bottom should be wide. Sand, gravel, and gravel (calcium chloride) are often spread along roads or paths to correct erosion.', 'Mountain erosion is not uncommon; the island is only partially submerged, and much of the mass of mountain erosion occurs below sea level.', 'The downside is that the ice will be in a loose position, so some triggers are needed to get it down, and some of the ice coming down the ledge can be a triggering event.', 'When the actual triggering event in the system is snowed in by the moon, and more snow falls by the mid-morning, other violent events, often by the mid-morning, are observed.', 'A depression is a cyclonic circulation that causes the winds of the surrounding region to move inwards and upwards.', 'Strong winds (often 100-200 mph) are generated and heavy objects can also rise into the air, bringing the wind to a standstill.', 'That wind begins as a gust of wind when it hits the rocks, and "blows" when it hits the ground.', 'Your VPN (Virtual Private Network) is a good way to avoid both censorship and commercial IP-geofiltering.', "They're better than other proxies for a number of reasons: they re-route all Internet traffic, not just http.", 'They offer excellent whitewater and high quality of service. They are encrypted and therefore are very flexible.', 'The media company has consistently lied about it, with some claiming it is for "black money."', 'In effect, the area code has no effect on the invalid copy; bit-for-bit copies of the disk run on the same device as the original.', "The real advantage is that they give companies more control over each other's markets; it's all about money.", "Because calls are routed over the Internet, you don't need to use the phone company where you live or where you live."]
# ["It's not necessary that you get the area number from the company you live in; you can get a satellite internet connection in the forests of Chican, Alaska, and choose a number that says you live in Sunny Arizona.", "Often, you'll need to purchase a different global number that allows you to call the PNG phone. You'll need to choose the number you want to call.", 'Real-Time Translator App - is an application that allows you to transfer the entire cast from one category to another.', 'Some applications that require this may also translate texts in foreign languages into actual text or other objects when the user points the smartphone at those objects.', 'Automatic engines have been modified to resemble nautical ones, and now often provide less and more accurate interpretation (and often not), but some care is needed, as it can still be understood quickly.', 'The most popular apps in this category are Google Translate, which allows offline translation by downloading the required language data.', "Using GPS navigation apps on your smartphone can be the easiest and most convenient way to navigate when you're out of the country.", 'This saves money by buying a GPS model, or renting a standard GPS device or a car.', "If you don't have data for your phone, or when it's out of range, you may or may not be able to get that data.", 'The prepaid phone card from each corner is filled with information for a wiki that can be used with a three-phone or regular telephone.', 'While most cards have numbers for calls, some countries specialize in offering call rates that are appropriate for specific teams.', 'Access to these services is by means of a toll-free telephone number, which can be used to make calls from any number.', 'Similar photocopies are also required in regular video recordings, even more so.', "If the item doesn't have a single image, you don't need to check your video record.", 'If using a drone, be sure to check first to see which movie you have access to and which tag permits or accompanying licenses you need.', "It's a bad idea to fly a drone over a seaport tank or a crowd, preferably in your area."]
# ['Overnight flights are booked directly by the airline, with the exception of late searches and fares.', "There can be a lot of prices on many different aggregators of mid-air flights, and it's a hassle to visit the airline's website before checking and booking search terms.", "While you may not need a visa for small businesses in some countries, like a paratrooper, or for a business, you'll need to stay up until you're ready to go, like an international student.", "Typically, you'll need to get a visa in advance in order to stay up until the end of the year.", 'Student visas are often required and exempt from the usual corporate or commercial visas.', "For many countries, you'll need a certificate from the venue you want to attend, as well as proof of income to support your performance for at least one year.", 'For details, you can contact the country you want to study in via email.', "When you need to apply for your diploma, working in France often means you'll need to apply for an income tax in the country where you live.", 'Income tax rates vary widely from country to country, and tax rates and tariffs vary widely from country to country.', 'In Asian countries, such as the United States and Canada, ice hockey is played both in the United States and in the United Kingdom, so the rate and format may vary from region to region.', "When you go to your mother's house but don't pay the rent or are unprofessional, price controls can be tricky.", "Make sure you know what you can and can't do and don't give away anything beyond legal limits.", 'The easiest way to start a small business is to revise your profile on a local blog site.', 'After saving the formatting and editing in Java, you can then build your website in JavaScript.', "The service is a great way to build rapport, but it's not the only one.", 'Living and working in a foreign country is known to be a different culture, a great way to meet new people, get to know yourself, get to know the Dutch, and even start a new business.']
# ['It can also be a good way to increase the budget to allow it to last longer because the company provides the staff with crates and boards and provides some flexibility.', 'Waterways are used to pass through the lagoon to the Black Sea and Caspian Sea. Parts of these roads can still be used. Available for special permits, which can be difficult to obtain.', "The White Sea-Baltic Canal empties into the Arctic Ocean's Baltic Sea, through Lake Anega, Lake Ladoga and Lake Petterberg, rising rivers and lakes.", "The Anega Lake is also connected to the Volga, where it is also accessible from the Caspian Sea via Rus '.", "Make sure that once you've lowered the marino, everything is clear. You'll meet with the other boat's crew and they'll tell you their story.", "As a matter of fact, you'll need to send a case notice asking for help, call the doctor, talk to the clean people you want, and then go to the local office to try to contact them.", "Try to reach out to as many people as you can. After a few delays, let everyone know and let them know what type of person you're looking for.", "In your selection, you will need to select your frequency flyer from the airline's destination.", "However, you may want to note that the airlines you're most likely to fly to include, you'll need to know that the special orders offered will always be different, and an increase in the fare charged by the airline may be more of an incentive.", 'Emirates, Etihad Airways, Qatar Airways, and Turkish Airlines have expanded their services to other parts of the world, and offer connections to other Asian cities at cheaper rates than other European airlines.', 'As of 2014, Turkish Airlines flies to 39 destinations in 30 countries.', 'If you have more options, check to see what your only rent for the island is in the table.', "For all those places outside of Africa, don't forget to check your visa, starting location, land survey, and contact information.", "If you're flying all over the globe, flights are limited to certain destinations and destinations due to the intercontinental climate.", 'No aircraft comes close to the three Great Lakes in the Gulf of Aden (and SkyTeam also does not cross any crossings).', 'However, the Star Alliance has completed everything from Santiago de Janeiro to Tahiti except for the Atlantic Ocean, which is the Latam Oneworld flight.']
# ["This isn't the only flight disaster if you're all but off the coast of Florida and California, USA. (see below)", 'In 1994, Azerbaijan came into conflict with the ethnic Armenian Azeris of the Nagorno-Karabakh region.', 'There was a new news series with Armenian support. However, none of the host countries were recognized by the press.', 'Political relations in the region and Azerbaijan were established.', 'The Canal District (Dutch: Lerachtengordel) is a 17th-century district in the vicinity of Bienenstadt, Amsterdam.', 'The entire district is recognized as a ᱭᱩ.ᱮᱱ.ᱤ.ᱮᱥ.ᱠᱳ World Heritage Site due to its distinct cultural and historical value, and its heritage value is among the highest in the country.', 'Cinque Terre, which means five hills, is made up of five small coastal villages of Rimaggiore, Manarola, Corniglia, Baranazza, and Monterosso, located in the Liguria region.', 'They are listed in the World Heritage List of ᱭᱩ.ᱮᱱ.ᱤᱹᱮᱥ.ᱠᱳ.', 'By the century, people were creating a peaceful environment with care for the sea-viewing islands, up to the sea-viewing dunes.', 'A significant part of this is the cost of visible corporate development. Roads, trains, and bridges run through villages, and cars cannot reach them.', 'The type of language spoken in Bel-Leu and Bizarre is slightly different from that of French, although it may be more closely related.', 'In particular, Arabic speakers such as Bel-Leu and Bizarre-Leu have some peculiarities in English that are slightly different from the French language, and some words have slightly different tones.', 'However, every English-speaking school and university has a standard language, so they may be able to understand you, maybe you can use the standard language.', 'In many parts of the world, handshaking is a form of physical exertion, denoting "exertion."', 'However, in China, very few rural residents recognize the sign, which means "to come," as a physical sign, a sign that is used in some developing countries, and must be encouraged.', 'Similarly, the return of a foreign national to Spain would have been a farewell event with a hand-to-hand combat as a sign.']
# ['Collaborative languages are creative languages that develop communication skills in people who experience communication skills.', 'They are distinct from the Bongua franca, which are native carbonic words that are a major cause of confusion in other linguistics.', 'On hot days, the natives may feel the smell that the water provides (as well as other things).', 'These can be disastrous - if the traveller searches for water, losing valuable energy and residual water.', 'Even so, the driest areas of the desert can be extremely cold at night. Hypothermia without red clothing is really dangerous.', "In winter, especially if you're planning a trip to rainforest areas, be sure to take your time. If you're driving through tropical rainforests, be careful.", "If you're driving through a tropical rainforest, you'll have a few hours in the car with the doors open when you get inside.", 'Bird flu, also known as bird swine flu, can infect both birds and mammals.', 'Fewer than a thousand cases of people have been reported, although many are asymptomatic.', 'Many of the people involved work as seamstresses, but bird watchers are also at risk.', "Norway's most common are high-altitude forts and forts, which tend to be high, low-lying, and prone to erosion.", 'These landmasses are commonly referred to as "thugs" which means a wide area, no open vegetation, no boundary.', 'In Rohtang Pass and Agra, they are commonly called "Hai" which means "no tree," and Maurya is usually surrounded by heath.', 'The glaciers are shallow, flowing only from the hills. It forms the western slopes, which can be covered by snowflakes.', 'Snow can damage the eyelids and eyelids and cover the back.', 'At the edges of the lilacs, large bumps rise, fall, and possibly fall from the edge of the bristles.']
# ['The hillside houses usually reach Charum during the summer months.', 'However, on colder days, they have a different kind of sunshine and humidity, take in more snow than usual at most railway stations, and offer activities such as skiing and snowboarding.', 'Some airlines offer unlimited fares, which reduces the cost of international travel.', 'The airlines that provide these services are Air Canada, Delta Airlines, Lufthansa for flights to and from Canada, and Lufthansa for flights to and from the UK.', 'In all cases, you can book by phone with the airline directly.']

# %%
with open("en_dev.txt", "w") as f:
    for translations in output:
        for translation in translations:
            f.write(translation + "\n")

# %%
# !pip install git+https://github.com/vmujadia/tokenizer.git --upgrade
# Out:
# Collecting git+https://github.com/vmujadia/tokenizer.git
#   Cloning https://github.com/vmujadia/tokenizer.git to /tmp/pip-req-build-kqncw88x
#   Running command git clone --filter=blob:none --quiet https://github.com/vmujadia/tokenizer.git /tmp/pip-req-build-kqncw88x
#   Resolved https://github.com/vmujadia/tokenizer.git to commit 93cd09b81702108a51c08c9796fd1cc941a1b98b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (2024.2.2)
# Building wheels for collected packages: IL-Tokenizer
#   Building wheel for IL-Tokenizer (setup.py) ... done
#   Created wheel for IL-Tokenizer: filename=IL_Tokenizer-0.0.2-py3-none-any.whl size=7225 sha256=4320661920199c010eaeaf1da89c820fef24dbb064f335b86b9b43ac80e5ad03
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mpn78b3_/wheels/9a/fb/5b/3d75bfde8561726121c09f0f0a83389c05312df8a513808c41
# Successfully built IL-Tokenizer
# Installing collected packages: IL-Tokenizer
# Successfully installed IL-Tokenizer-0.0.2

# %%
from ilstokenizer import tokenizer

# %%
from sacrebleu import corpus_bleu

# Step 1: Read the translated output
translated_output_file = "en_dev.txt" 
translated_output = []
with open(translated_output_file, "r") as f:
    for line in f:
        translated_output.append(line.strip())

# Step 2: Read the reference translations
reference_file = "/kaggle/input/sat-eng-testset/dev.eng_Latn"  
reference_translations = []
with open(reference_file, "r") as f:
    for line in f:
        reference_translations.append(line.strip())

# Step 3: Tokenize the translated output and reference translations
tokenized_output = [tokenizer.tokenize(sentence).lower() for sentence in translated_output]
tokenized_references = [[tokenizer.tokenize(sentence).lower()] for sentence in reference_translations]

# Step 4: Compute the BLEU score
bleu_score = corpus_bleu(tokenized_output, tokenized_references)
print("BLEU score:", bleu_score.score)
# Out:
# BLEU score: 17.26594785116016
