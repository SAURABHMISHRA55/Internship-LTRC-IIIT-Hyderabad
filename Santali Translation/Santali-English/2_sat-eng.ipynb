# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sat-eng-dataset/dev.sat_Olck
# /kaggle/input/sat-eng-dataset/dev.eng_Latn
# /kaggle/input/sat-eng-dataset/train.sat_Olck
# /kaggle/input/sat-eng-dataset/train.eng_Latn

# %%
# !pip install torch==2.2.1 torchvision==0.17.1 torchaudio==2.2.1
# Out:
# Collecting torch==2.2.1
#   Downloading torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.17.1
#   Downloading torchvision-0.17.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting torchaudio==2.2.1
#   Downloading torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.2.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch==2.2.1) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.2.1) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.2.1) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.2.1) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.2.1) (2024.3.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.1)
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.17.1) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.17.1) (9.5.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.2.1) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.2.1) (1.3.0)
# Downloading torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.3 MB/s eta 0:00:00:00:0100:01
# Downloading torchvision-0.17.1-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 70.8 MB/s eta 0:00:00:00:0100:01
# Downloading torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 75.8 MB/s eta 0:00:00:00:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 84.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 71.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 9.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.7 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 75.7 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.2
#     Uninstalling torchvision-0.16.2:
#       Successfully uninstalled torchvision-0.16.2
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.1.2
#     Uninstalling torchaudio-2.1.2:
#       Successfully uninstalled torchaudio-2.1.2
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 torch-2.2.1 torchaudio-2.2.1 torchvision-0.17.1 triton-2.2.0

# %%
# !git clone https://github.com/pytorch/fairseq.git
# %cd fairseq
#!git checkout v0.10.2
##!python -m pip install --user ./
# !pip install --editable .
# %cd ..
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35209, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 35209 (delta 68), reused 84 (delta 49), pack-reused 35083
# Receiving objects: 100% (35209/35209), 25.23 MiB | 33.29 MiB/s, done.
# Resolving deltas: 100% (25558/25558), done.
# /kaggle/working/fairseq
# Obtaining file:///kaggle/working/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.16.0)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (3.0.8)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.21.3 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.26.4)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2023.12.25)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2)
#   Downloading sacrebleu-2.4.2-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.2.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (4.66.4)
# Collecting bitarray (from fairseq==0.12.2)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: torchaudio>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.2.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.2.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (21.3)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.* in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (6.0.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (4.9.0)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (5.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->fairseq==0.12.2) (12.5.82)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi->fairseq==0.12.2) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->fairseq==0.12.2) (3.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13->fairseq==0.12.2) (1.3.0)
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 8.1 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 6.9 MB/s eta 0:00:00
# Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 14.8 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-0.editable-cp310-cp310-linux_x86_64.whl size=9582 sha256=4826886ef0687ce7d7f2880ea374a22276b2df280b19635bfc9b021f45cbdcd1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p84ryo1q/wheels/67/69/06/aa788a7d879a7513f5f2e5c6d56825b6813783cb55ac5c7f8d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141210 sha256=a05947f3aea6a7d7d7af450ff5d8dfd7229d7a250db2e8db122f65fd8d5b79e6
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: bitarray, antlr4-python3-runtime, portalocker, omegaconf, sacrebleu, hydra-core, fairseq
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.9.2 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.10.1 sacrebleu-2.4.2
# /kaggle/working

# %%
# !pip install git+https://github.com/vmujadia/tokenizer.git --upgrade
# Out:
# Collecting git+https://github.com/vmujadia/tokenizer.git
#   Cloning https://github.com/vmujadia/tokenizer.git to /tmp/pip-req-build-ci5dew4t
#   Running command git clone --filter=blob:none --quiet https://github.com/vmujadia/tokenizer.git /tmp/pip-req-build-ci5dew4t
#   Resolved https://github.com/vmujadia/tokenizer.git to commit 93cd09b81702108a51c08c9796fd1cc941a1b98b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (2024.2.2)
# Building wheels for collected packages: IL-Tokenizer
#   Building wheel for IL-Tokenizer (setup.py) ... done
#   Created wheel for IL-Tokenizer: filename=IL_Tokenizer-0.0.2-py3-none-any.whl size=7225 sha256=f3ea22f87bf1d5153b44e4e04d86a7ea6f9b2705c2d6f852b5155f35c8ea4f7a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7jl8146y/wheels/9a/fb/5b/3d75bfde8561726121c09f0f0a83389c05312df8a513808c41
# Successfully built IL-Tokenizer
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: IL-Tokenizer
# Successfully installed IL-Tokenizer-0.0.2

# %%
# !git clone https://github.com/moses-smt/mosesdecoder.git
# Out:
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 148459, done.
# remote: Counting objects: 100% (887/887), done.
# remote: Compressing objects: 100% (366/366), done.
# remote: Total 148459 (delta 565), reused 797 (delta 517), pack-reused 147572
# Receiving objects: 100% (148459/148459), 129.99 MiB | 25.57 MiB/s, done.
# Resolving deltas: 100% (114591/114591), done.

# %%
# !git clone https://github.com/rsennrich/subword-nmt.git
# Out:
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 615, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 615 (delta 20), reused 24 (delta 14), pack-reused 576
# Receiving objects: 100% (615/615), 259.20 KiB | 7.85 MiB/s, done.
# Resolving deltas: 100% (369/369), done.

# %%
# !ls mosesdecoder/scripts/training/clean-corpus-n.perl
# Out:
# mosesdecoder/scripts/training/clean-corpus-n.perl

# %%
# !cp /kaggle/input/sat-eng-dataset/train.eng_Latn train.tgt
# !cp /kaggle/input/sat-eng-dataset/train.sat_Olck train.src
# !cp /kaggle/input/sat-eng-dataset/dev.eng_Latn valid.tgt
# !cp /kaggle/input/sat-eng-dataset/dev.sat_Olck valid.src

# %%
print ('Data Stats')
! wc -l train.*
! wc -l valid.*
# Out:
# Data Stats
#   22536 train.src
#   22536 train.tgt
#   45072 total
#    997 valid.src
#    997 valid.tgt
#   1994 total

# %%
from ilstokenizer import tokenizer
import codecs

def to_tokenize_and_lower(input_path, output_path):
    outfile = open(output_path, 'w')
    for line in codecs.open(input_path):
        line = line.strip()
        line = tokenizer.tokenize(line).lower()
        #print (line)
        outfile.write(line+'\n')
    outfile.close()

# %%
to_tokenize_and_lower('train.src','train.src.tkn')
to_tokenize_and_lower('train.tgt','train.tgt.tkn')

to_tokenize_and_lower('valid.src','valid.src.tkn')
to_tokenize_and_lower('valid.tgt','valid.tgt.tkn')

# %%
! cat train.src.tkn > train.all.tkn
! cat train.tgt.tkn >> train.all.tkn

# %%
! perl mosesdecoder/scripts/training/clean-corpus-n.perl -ratio 1.5 train src.tkn tgt.tkn train_filtered 1 250
# Out:
# clean-corpus.perl: processing train.src.tkn & .tgt.tkn to train_filtered, cutoff 1-250, ratio 1.5
# ..
# Input sentences: 22536  Output sentences:  21996

# %%
print ('Data Stats')
! wc -l train*
! wc -l valid*
# Out:
# Data Stats
#    45072 train.all.tkn
#    22536 train.src
#    22536 train.src.tkn
#    22536 train.tgt
#    22536 train.tgt.tkn
#    21996 train_filtered.src.tkn
#    21996 train_filtered.tgt.tkn
#   179208 total
#    997 valid.src
#    997 valid.src.tkn
#    997 valid.tgt
# %%
import os
os.environ['PYTHONPATH'] += ":/content/fairseq/"

! echo $PYTHONPATH
# Out:
# /kaggle/lib/kagglegym:/kaggle/lib:/content/fairseq/

# %%
! python fairseq/fairseq_cli/preprocess.py \
    --joined-dictionary \
    --source-lang sat --target-lang en \
    --trainpref train --validpref valid --testpref valid \
    --destdir data-bin/trial --thresholdtgt 0 --thresholdsrc 0 \
    --workers 20
# Out:
# 2024-07-30 13:49:23.151067: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-30 13:49:23.151176: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-30 13:49:23.289887: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /kaggle/working/fairseq/fairseq/tasks/multires_hubert_pretraining.py:154: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   dictionaries = [ (Dictionary.load(f"{label_dir}/dict.{label}.txt") if label is not "" else None ) for label in self.cfg.labels]
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
ls data-bin/trial
# Out:
# dict.en.txt         test.sat-en.sat.bin   train.sat-en.sat.idx
# dict.sat.txt        test.sat-en.sat.idx   valid.sat-en.en.bin
# preprocess.log      train.sat-en.en.bin   valid.sat-en.en.idx
# test.sat-en.en.bin  train.sat-en.en.idx   valid.sat-en.sat.bin
# test.sat-en.en.idx  train.sat-en.sat.bin  valid.sat-en.sat.idx

# %%
! python fairseq/fairseq_cli/train.py --fp16 \
    data-bin/trial \
    --source-lang sat --target-lang en \
    --arch transformer_wmt_en_de --share-all-embeddings \
    --encoder-embed-dim 512 --encoder-ffn-embed-dim 2048 \
    --encoder-layers 6 --encoder-attention-heads 8 \
    --decoder-embed-dim 512 --decoder-ffn-embed-dim 2048 \
    --decoder-layers 6 --decoder-attention-heads 8 \
    --dropout 0.3 --weight-decay 0.0 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 0.0007 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --max-tokens 4096 --update-freq 16 \
    --max-update 1460 \
    --keep-last-epochs 10 \
    --save-dir trained_models
# Out:
# 2024-07-30 13:50:57.509307: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-30 13:50:57.509363: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-30 13:50:57.511159: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# epoch 001:   0%|                                         | 0/16 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:5109: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# epoch 001:  94%|██████████████████████████████  | 15/16 [00:46<00:02,  2.87s/it]
# epoch 001 | valid on 'valid' subset:   0%|               | 0/17 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  12%|▊      | 2/17 [00:00<00:01, 14.97it/s]
# epoch 001 | valid on 'valid' subset:  24%|█▋     | 4/17 [00:00<00:00, 15.36it/s]
# epoch 001 | valid on 'valid' subset:  35%|██▍    | 6/17 [00:00<00:00, 16.25it/s]
# epoch 001 | valid on 'valid' subset:  47%|███▎   | 8/17 [00:00<00:00, 16.68it/s]
# epoch 001 | valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.44it/s]
# epoch 001 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.48it/s]
# epoch 001 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.25it/s]
# epoch 001 | valid on 'valid' subset:  94%|█████▋| 16/17 [00:01<00:00, 15.64it/s]
# epoch 002:  94%|██████████████████████████████  | 15/16 [00:43<00:02,  2.87s/it]
# epoch 002 | valid on 'valid' subset:   0%|               | 0/17 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:  12%|▊      | 2/17 [00:00<00:00, 15.27it/s]
# epoch 002 | valid on 'valid' subset:  24%|█▋     | 4/17 [00:00<00:00, 15.41it/s]
# epoch 002 | valid on 'valid' subset:  35%|██▍    | 6/17 [00:00<00:00, 16.27it/s]
# epoch 002 | valid on 'valid' subset:  47%|███▎   | 8/17 [00:00<00:00, 16.69it/s]
# epoch 002 | valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.43it/s]
# epoch 002 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.51it/s]
# epoch 002 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.31it/s]
# epoch 002 | valid on 'valid' subset:  94%|█████▋| 16/17 [00:00<00:00, 15.69it/s]
# epoch 003:  94%|██████████████████████████████  | 15/16 [00:43<00:02,  2.89s/it]
# epoch 003 | valid on 'valid' subset:   0%|               | 0/17 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:  12%|▊      | 2/17 [00:00<00:00, 15.34it/s]
# epoch 003 | valid on 'valid' subset:  24%|█▋     | 4/17 [00:00<00:00, 15.39it/s]
# epoch 003 | valid on 'valid' subset:  35%|██▍    | 6/17 [00:00<00:00, 16.29it/s]
# epoch 003 | valid on 'valid' subset:  47%|███▎   | 8/17 [00:00<00:00, 16.69it/s]
# epoch 003 | valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.41it/s]
# epoch 003 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.46it/s]
# epoch 003 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.25it/s]
# epoch 003 | valid on 'valid' subset:  94%|█████▋| 16/17 [00:00<00:00, 15.68it/s]
# epoch 004:  94%|██████████████████████████████  | 15/16 [00:43<00:02,  2.89s/it]
# epoch 004 | valid on 'valid' subset:   0%|               | 0/17 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:  12%|▊      | 2/17 [00:00<00:00, 15.53it/s]
# epoch 004 | valid on 'valid' subset:  24%|█▋     | 4/17 [00:00<00:00, 15.45it/s]
# epoch 004 | valid on 'valid' subset:  35%|██▍    | 6/17 [00:00<00:00, 16.35it/s]
# epoch 004 | valid on 'valid' subset:  47%|███▎   | 8/17 [00:00<00:00, 16.73it/s]
# epoch 004 | valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.46it/s]
# epoch 004 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.49it/s]
# epoch 004 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.11it/s]
# epoch 004 | valid on 'valid' subset:  94%|█████▋| 16/17 [00:01<00:00, 15.49it/s]
# epoch 005:  94%|██████████████████████████████  | 15/16 [00:43<00:02,  2.91s/it]
# epoch 005 | valid on 'valid' subset:   0%|               | 0/17 [00:00<?, ?it/s]
# epoch 005 | valid on 'valid' subset:  12%|▊      | 2/17 [00:00<00:00, 15.33it/s]
# epoch 005 | valid on 'valid' subset:  24%|█▋     | 4/17 [00:00<00:00, 15.40it/s]
# epoch 005 | valid on 'valid' subset:  35%|██▍    | 6/17 [00:00<00:00, 16.30it/s]
# epoch 005 | valid on 'valid' subset:  47%|███▎   | 8/17 [00:00<00:00, 16.71it/s]
# epoch 005 | valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.44it/s]
# epoch 005 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.51it/s]
# epoch 005 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.29it/s]
# epoch
| valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.39it/s]
# epoch 089 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.47it/s]
# epoch 089 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.24it/s]
# epoch 089 | valid on 'valid' subset:  94%|█████▋| 16/17 [00:00<00:00, 15.63it/s]
# epoch 090:  94%|██████████████████████████████  | 15/16 [00:43<00:02,  2.90s/it]
# epoch 090 | valid on 'valid' subset:   0%|               | 0/17 [00:00<?, ?it/s]
# epoch 090 | valid on 'valid' subset:  12%|▊      | 2/17 [00:00<00:01, 14.53it/s]
# epoch 090 | valid on 'valid' subset:  24%|█▋     | 4/17 [00:00<00:00, 15.02it/s]
# epoch 090 | valid on 'valid' subset:  35%|██▍    | 6/17 [00:00<00:00, 16.07it/s]
# epoch 090 | valid on 'valid' subset:  47%|███▎   | 8/17 [00:00<00:00, 16.56it/s]
# epoch 090 | valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.34it/s]
# epoch 090 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.45it/s]
# epoch 090 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.25it/s]
# epoch 090 | valid on 'valid' subset:  94%|█████▋| 16/17 [00:01<00:00, 15.64it/s]
# epoch 091:  94%|██████████████████████████████  | 15/16 [00:43<00:02,  2.89s/it]
# epoch 091 | valid on 'valid' subset:   0%|               | 0/17 [00:00<?, ?it/s]
# epoch 091 | valid on 'valid' subset:  12%|▊      | 2/17 [00:00<00:00, 15.57it/s]
# epoch 091 | valid on 'valid' subset:  24%|█▋     | 4/17 [00:00<00:00, 15.55it/s]
# epoch 091 | valid on 'valid' subset:  35%|██▍    | 6/17 [00:00<00:00, 16.39it/s]
# epoch 091 | valid on 'valid' subset:  47%|███▎   | 8/17 [00:00<00:00, 16.80it/s]
# epoch 091 | valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.49it/s]
# epoch 091 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.54it/s]
# epoch 091 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.30it/s]
# epoch 091 | valid on 'valid' subset:  94%|█████▋| 16/17 [00:00<00:00, 15.69it/s]
# epoch 092:  50%|████████████████▌                | 8/16 [00:23<00:23,  2.88s/it]
# epoch 092 | valid on 'valid' subset:   0%|               | 0/17 [00:00<?, ?it/s]
# epoch 092 | valid on 'valid' subset:  12%|▊      | 2/17 [00:00<00:00, 15.61it/s]
# epoch 092 | valid on 'valid' subset:  24%|█▋     | 4/17 [00:00<00:00, 15.41it/s]
# epoch 092 | valid on 'valid' subset:  35%|██▍    | 6/17 [00:00<00:00, 16.33it/s]
# epoch 092 | valid on 'valid' subset:  47%|███▎   | 8/17 [00:00<00:00, 16.71it/s]
# epoch 092 | valid on 'valid' subset:  59%|███▌  | 10/17 [00:00<00:00, 16.42it/s]
# epoch 092 | valid on 'valid' subset:  71%|████▏ | 12/17 [00:00<00:00, 16.46it/s]
# epoch 092 | valid on 'valid' subset:  82%|████▉ | 14/17 [00:00<00:00, 16.17it/s]
# epoch 092 | valid on 'valid' subset:  94%|█████▋| 16/17 [00:01<00:00, 15.58it/s]

# %%
ls trained_models
# Out:
# checkpoint82.pt  checkpoint85.pt  checkpoint88.pt  checkpoint91.pt
# checkpoint83.pt  checkpoint86.pt  checkpoint89.pt  checkpoint_best.pt
# checkpoint84.pt  checkpoint87.pt  checkpoint90.pt  checkpoint_last.pt

# %%
! python fairseq/fairseq_cli/interactive.py  data-bin/trial \
    -s sat -t en \
    --distributed-world-size 1  \
    --path trained_models/checkpoint_best.pt \
    --batch-size 64  --buffer-size 2500 --beam 10 \
    --skip-invalid-size-inputs-valid-test \
    --input valid.sat > valid.en.translated
# Out:
# 2024-07-30 15:10:14.667904: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-30 15:10:14.667963: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-30 15:10:14.670129: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from sacrebleu import corpus_bleu

# Step 1: Read the translated output
translated_output_file = "valid.en.translated" 
translated_output = []
with open(translated_output_file, "r") as f:
    for line in f:
        translated_output.append(line.strip())

# Step 2: Read the reference translations
reference_file = "valid.en"  
reference_translations = []
with open(reference_file, "r") as f:
    for line in f:
        reference_translations.append(line.strip())

# Step 3: Tokenize the translated output and reference translations
tokenized_output = [tokenizer.tokenize(sentence).lower() for sentence in translated_output]
tokenized_references = [[tokenizer.tokenize(sentence).lower()] for sentence in reference_translations]

# Step 4: Compute the BLEU score
bleu_score = corpus_bleu(tokenized_output, tokenized_references)
print("BLEU score:", bleu_score.score)
# Out:
# BLEU score: 6.915029860134529
