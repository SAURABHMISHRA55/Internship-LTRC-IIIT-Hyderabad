# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/florestestingdata/devtest.eng_Latn
# /kaggle/input/florestestingdata/devtest.hin_Deva

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !git clone https://github.com/pytorch/fairseq.git
# %cd fairseq
#!git checkout v0.10.2
##!python -m pip install --user ./
# !pip install --editable .
# %cd ..
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35203, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 35203 (delta 66), reused 80 (delta 48), pack-reused 35083
# Receiving objects: 100% (35203/35203), 25.23 MiB | 23.19 MiB/s, done.
# Resolving deltas: 100% (25556/25556), done.
# /kaggle/working/fairseq
# Obtaining file:///kaggle/working/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.16.0)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (3.0.8)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.21.3 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.26.4)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2023.12.25)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2)
#   Downloading sacrebleu-2.4.2-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (4.66.4)
# Collecting bitarray (from fairseq==0.12.2)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: torchaudio>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.1.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.2.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (21.3)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.* in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (6.0.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (4.9.0)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (5.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (2024.3.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi->fairseq==0.12.2) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->fairseq==0.12.2) (3.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13->fairseq==0.12.2) (1.3.0)
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 8.9 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 8.0 MB/s eta 0:00:00
# Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 22.0 MB/s eta 0:00:00
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-0.editable-cp310-cp310-linux_x86_64.whl size=9572 sha256=5dcdf0a1e078bafa7549d3c32e1de572df5461dffa8620e73059b79daeee3677
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sr6ocult/wheels/67/69/06/aa788a7d879a7513f5f2e5c6d56825b6813783cb55ac5c7f8d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141210 sha256=67d42130ebf78f66b13bb5cbc3a42cd65586be6430086df5da5baa2f2ed2f51e
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: bitarray, antlr4-python3-runtime, portalocker, omegaconf, sacrebleu, hydra-core, fairseq
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.9.2 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.8.2 sacrebleu-2.4.2
# /kaggle/working

# %%
# !pip install git+https://github.com/vmujadia/tokenizer.git --upgrade
# Out:
# Collecting git+https://github.com/vmujadia/tokenizer.git
#   Cloning https://github.com/vmujadia/tokenizer.git to /tmp/pip-req-build-mt_kluhl
#   Running command git clone --filter=blob:none --quiet https://github.com/vmujadia/tokenizer.git /tmp/pip-req-build-mt_kluhl
#   Resolved https://github.com/vmujadia/tokenizer.git to commit 93cd09b81702108a51c08c9796fd1cc941a1b98b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (2024.2.2)
# Building wheels for collected packages: IL-Tokenizer
#   Building wheel for IL-Tokenizer (setup.py) ... done
#   Created wheel for IL-Tokenizer: filename=IL_Tokenizer-0.0.2-py3-none-any.whl size=7225 sha256=c00b93e368c311ef6e2f0ca110b942756169e883fd869875d2a1eb12aa698dd0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z3uh1p4s/wheels/9a/fb/5b/3d75bfde8561726121c09f0f0a83389c05312df8a513808c41
# Successfully built IL-Tokenizer
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: IL-Tokenizer
# Successfully installed IL-Tokenizer-0.0.2

# %%
# !git clone https://github.com/moses-smt/mosesdecoder.git
# Out:
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 148459, done.
# remote: Counting objects: 100% (887/887), done.
# remote: Compressing objects: 100% (366/366), done.
# remote: Total 148459 (delta 565), reused 797 (delta 517), pack-reused 147572
# Receiving objects: 100% (148459/148459), 129.99 MiB | 21.72 MiB/s, done.
# Resolving deltas: 100% (114591/114591), done.

# %%
# !git clone https://github.com/rsennrich/subword-nmt.git
# Out:
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 600, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 600 (delta 10), reused 12 (delta 4), pack-reused 576
# Receiving objects: 100% (600/600), 253.58 KiB | 8.18 MiB/s, done.
# Resolving deltas: 100% (359/359), done.

# %%
# !ls mosesdecoder/scripts/training/clean-corpus-n.perl
# Out:
# mosesdecoder/scripts/training/clean-corpus-n.perl

# %%
from datasets import load_dataset

dataset = load_dataset("cfilt/iitb-english-hindi")

train_dataset = dataset['train']
valid_dataset = dataset['validation']

print("Training data sample:", train_dataset[0])
print("Validation data sample:", valid_dataset[0])
# Out:
# Downloading readme:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/190M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/85.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1659083 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/520 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2507 [00:00<?, ? examples/s]
# Training data sample: {'translation': {'en': 'Give your application an accessibility workout', 'hi': 'अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें'}}
# Validation data sample: {'translation': {'en': 'Students of the Dattatreya city Municipal corporation secondary school demonstrated their imagination power by creating the fictitious fort "Duttgarh".', 'hi': "महानगर पालिका अंतर्गत दत्तात्रय नगर माध्यमिक स्कूल के विद्यार्थियों ने काल्पनिक किला 'दत्तगढ़' बनाकर अपनी कल्पनाशक्ति का परिचय दिया।"}}

# %%
import random

sample_size = 200000
train_samples = random.sample(list(train_dataset), sample_size)

# %%
train_src_path = "train.src"
train_tgt_path = "train.tgt"
valid_src_path = "valid.src"
valid_tgt_path = "valid.tgt"

with open(train_src_path, 'w', encoding='utf-8') as train_src_file, \
     open(train_tgt_path, 'w', encoding='utf-8') as train_tgt_file:
    for example in train_samples:
        train_src_file.write(example['translation']['en'] + '\n')
        train_tgt_file.write(example['translation']['hi'] + '\n')

with open(valid_src_path, 'w', encoding='utf-8') as valid_src_file, \
     open(valid_tgt_path, 'w', encoding='utf-8') as valid_tgt_file:
    for example in valid_dataset:
        valid_src_file.write(example['translation']['en'] + '\n')
        valid_tgt_file.write(example['translation']['hi'] + '\n')

# %%
print ('Data Stats')
! wc -l train.*
! wc -l valid.*
# Out:
# Data Stats
#   200000 train.src
#   200000 train.tgt
#   400000 total
#    520 valid.src
#    520 valid.tgt
#   1040 total

# %%
from ilstokenizer import tokenizer
import codecs

def to_tokenize_and_lower(input_path, output_path):
    outfile = open(output_path, 'w')
    for line in codecs.open(input_path):
        line = line.strip()
        line = tokenizer.tokenize(line).lower()
        #print (line)
        outfile.write(line+'\n')
    outfile.close()

# %%
to_tokenize_and_lower('train.src','train.src.tkn')
to_tokenize_and_lower('train.tgt','train.tgt.tkn')

to_tokenize_and_lower('valid.src','valid.src.tkn')
to_tokenize_and_lower('valid.tgt','valid.tgt.tkn')

# %%
! cat train.src.tkn > train.all.tkn
! cat train.tgt.tkn >> train.all.tkn

# %%
! perl mosesdecoder/scripts/training/clean-corpus-n.perl -ratio 1.5 train src.tkn tgt.tkn train_filtered 1 250
# Out:
# clean-corpus.perl: processing train.src.tkn & .tgt.tkn to train_filtered, cutoff 1-250, ratio 1.5
# ..........(100000)..........(200000)
# Input sentences: 200000  Output sentences:  166094

# %%
print ('Data Stats')
! wc -l train*
! wc -l valid*
# Out:
# Data Stats
#    400000 train.all.tkn
#    200000 train.src
#    200000 train.src.tkn
#    200000 train.tgt
#    200000 train.tgt.tkn
#    166094 train_filtered.src.tkn
#    166094 train_filtered.tgt.tkn
#   1532188 total
#    520 valid.src
#    520 valid.src.tkn
#    520 valid.tgt
#    520 valid.tgt.tkn
#   2080 total

# %%
# !python subword-nmt/subword_nmt/learn_bpe.py -s 5500 < train.all.tkn > train.codes
# Out:
# 100%|######################################| 5500/5500 [00:24<00:00, 220.54it/s]

# %%
! head -n 10 train.codes
# Out:
# #version: 0.2
# t h
# i n
# a n
# th e</w>
# क े</w>
# r e
# ् र
# े ं</w>
# t i

# %%
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < train.src.tkn > train.en
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < train.tgt.tkn > train.hi

# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < valid.src.tkn > valid.en
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < valid.tgt.tkn > valid.hi

# %%
! head -n 10 train.en
# Out:
# “@@ and we@@ i@@ gh with a pro@@ per bal@@ ance . ”
# j@@ at
# el@@ ection of president , problems of im@@ pe@@ ach@@ ment of president , pow@@ ers , inter@@ nal position of president in parliament , parliam@@ ent@@ ary pow@@ ers f president and em@@ er@@ gen@@ cy pow@@ ers of president are exp@@ la@@ ined in this cha@@ p@@ ter .
# witness
# is equal to
# the stu@@ dy of here@@ d@@ ity is , therefore , the stu@@ dy of gen@@ es and ch@@ ro@@ mo@@ s@@ omes .
# j@@ ad@@ u n@@ ath singh
# the cra@@ f@@ t@@ s@@ men formed the basis of han@@ dic@@ ra@@ ft production .
# folder name
# the du@@ t@@ ts of ra@@ mb@@ ag@@ an the du@@ t@@ ts came origin@@ ally from a@@ j@@ ap@@ u@@ r , in the bur@@ d@@ w@@ an district of bengal .

# %%
! head -n 10 train.hi
# Out:
# और तुम ( जब तौ@@ लो तो ) ठीक तरा@@ ज़@@ ू से ड@@ न्@@ डी सी@@ धी रख@@ कर तौ@@ लो
# जा@@ ट
# राष्ट्रपति का चु@@ नाव उस पर महा@@ भि@@ योग की अव@@ स्था@@ एँ उसकी शक्ति@@ याँ संविधान के अन्@@ तर्@@ गत राष्ट्रपति की स्थिति राष्ट्रपति की सं@@ सद@@ ीय शक्ति तथा राष्ट्रपति की वि@@ वे@@ का@@ ध@@ ीन श@@ क्तियों का वर्णन इस अध्या@@ य में किया गया है ।
# सा@@ ख
# से समान है
# अंत : आ@@ नु@@ वं@@ शि@@ कता का अध्ययन वस्तु@@ त : जी@@ नों तथा गुण@@ सू@@ त्रों का ही अध्ययन है .
# य@@ दु@@ नाथ सिंह
# ह@@ स्त@@ शि@@ ल्@@ प उत्पादन में मुख्य स्थान शि@@ ल्@@ प@@ कारों का था ।
# फ़ोल्डर मा@@ लिक
# ३ राम@@ बा@@ गा@@ न का द@@ त्त घ@@ रा@@ ना द@@ त्त - घ@@ रा@@ ने के कु@@ ल@@ वृ@@ द्ध नी@@ ल@@ म@@ ण@@ ि द@@ त्त बंगाल के बर्@@ द्@@ द@@ वान जि@@ ले के आ@@ जा@@ पुर गा@@ ँ@@ व के थे ।

# %%
import os
os.environ['PYTHONPATH'] += ":/content/fairseq/"

! echo $PYTHONPATH
# Out:
# /kaggle/lib/kagglegym:/kaggle/lib:/content/fairseq/

# %%
! python fairseq/fairseq_cli/preprocess.py \
    --joined-dictionary \
    --source-lang en --target-lang hi \
    --trainpref train --validpref valid --testpref valid \
    --destdir data-bin/trial --thresholdtgt 0 --thresholdsrc 0 \
    --workers 20
# Out:
# 2024-06-21 12:14:03.134557: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-21 12:14:03.134693: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-21 12:14:03.292537: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /kaggle/working/fairseq/fairseq/tasks/multires_hubert_pretraining.py:154: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   dictionaries = [ (Dictionary.load(f"{label_dir}/dict.{label}.txt") if label is not "" else None ) for label in self.cfg.labels]
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
ls data-bin/trial
# Out:
# dict.en.txt        test.en-hi.en.idx   train.en-hi.en.idx  valid.en-hi.en.idx
# dict.hi.txt        test.en-hi.hi.bin   train.en-hi.hi.bin  valid.en-hi.hi.bin
# preprocess.log     test.en-hi.hi.idx   train.en-hi.hi.idx  valid.en-hi.hi.idx
# test.en-hi.en.bin  train.en-hi.en.bin  valid.en-hi.en.bin

# %%
! python fairseq/fairseq_cli/train.py --fp16 \
    data-bin/trial \
    --source-lang en --target-lang hi \
    --arch transformer_iwslt_de_en --share-all-embeddings \
    --encoder-embed-dim	128 --encoder-ffn-embed-dim	128 \
    --encoder-layers	4 --encoder-attention-heads	2 \
    --decoder-embed-dim	128 --decoder-ffn-embed-dim	128 \
    --decoder-layers	4 --decoder-attention-heads	2 \
    --dropout 0.3 --weight-decay 0.0 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 0.01 --lr-scheduler inverse_sqrt --warmup-updates 10 \
    --max-tokens 4096 --update-freq 16 \
    --max-update 4000 \
    --keep-last-epochs	10 \
    --save-dir trained_models
# Out:
# 2024-06-21 12:16:12.570036: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06
| valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 034 | valid on 'valid' subset:  57%|████▌   | 4/7 [00:00<00:00, 35.68it/s]
# epoch 035:  99%|▉| 93/94 [01:03<00:00,  1.53it/s, loss=7.54, nll_loss=6.634, ppl
# epoch 035 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 035 | valid on 'valid' subset:  43%|███▍    | 3/7 [00:00<00:00, 29.16it/s]
# epoch 036:  99%|▉| 93/94 [01:03<00:00,  1.49it/s, loss=7.526, nll_loss=6.619, pp
# epoch 036 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 036 | valid on 'valid' subset:  57%|████▌   | 4/7 [00:00<00:00, 36.71it/s]
# epoch 037:  99%|▉| 93/94 [01:03<00:00,  1.46it/s, loss=7.522, nll_loss=6.613, pp
# epoch 037 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 037 | valid on 'valid' subset:  57%|████▌   | 4/7 [00:00<00:00, 35.42it/s]
# epoch 038:  99%|▉| 93/94 [01:03<00:00,  1.47it/s, loss=7.492, nll_loss=6.579, pp
# epoch 038 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 038 | valid on 'valid' subset:  43%|███▍    | 3/7 [00:00<00:00, 29.71it/s]
# epoch 039:  99%|▉| 93/94 [01:03<00:00,  1.46it/s, loss=7.491, nll_loss=6.578, pp
# epoch 039 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 039 | valid on 'valid' subset:  43%|███▍    | 3/7 [00:00<00:00, 27.41it/s]
# epoch 040:  99%|▉| 93/94 [01:03<00:00,  1.47it/s, loss=7.477, nll_loss=6.561, pp
# epoch 040 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 040 | valid on 'valid' subset:  43%|███▍    | 3/7 [00:00<00:00, 29.43it/s]
# epoch 041:  99%|▉| 93/94 [01:04<00:00,  1.48it/s, loss=7.469, nll_loss=6.553, pp
# epoch 041 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 041 | valid on 'valid' subset:  43%|███▍    | 3/7 [00:00<00:00, 29.74it/s]
# epoch 042:  99%|▉| 93/94 [01:03<00:00,  1.45it/s, loss=7.453, nll_loss=6.534, pp
# epoch 042 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 042 | valid on 'valid' subset:  43%|███▍    | 3/7 [00:00<00:00, 29.93it/s]
# epoch 043:  66%|█████████████████████           | 62/94 [00:42<00:21,  1.46it/s]
# epoch 043 | valid on 'valid' subset:   0%|                | 0/7 [00:00<?, ?it/s]
# epoch 043 | valid on 'valid' subset:  43%|███▍    | 3/7 [00:00<00:00, 29.87it/s]

# %%
ls trained_models
# Out:
# checkpoint33.pt  checkpoint36.pt  checkpoint39.pt  checkpoint42.pt
# checkpoint34.pt  checkpoint37.pt  checkpoint40.pt  checkpoint_best.pt
# checkpoint35.pt  checkpoint38.pt  checkpoint41.pt  checkpoint_last.pt

# %%
! python fairseq/fairseq_cli/interactive.py  data-bin/trial \
    -s en -t hi \
    --distributed-world-size 1  \
    --path trained_models/checkpoint_best.pt \
    --batch-size 64  --buffer-size 2500 --beam 10 \
    --skip-invalid-size-inputs-valid-test \
    --input valid.en > valid.hi.translated
# Out:
# 2024-06-21 13:04:17.536397: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-21 13:04:17.536472: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-21 13:04:17.538289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from sacrebleu import corpus_bleu

# Step 1: Read the translated output
translated_output_file = "valid.hi.translated" 
translated_output = []
with open(translated_output_file, "r") as f:
    for line in f:
        translated_output.append(line.strip())

# Step 2: Read the reference translations
reference_file = "valid.hi"  
reference_translations = []
with open(reference_file, "r") as f:
    for line in f:
        reference_translations.append(line.strip())

# Step 3: Tokenize the translated output and reference translations
tokenized_output = [tokenizer.tokenize(sentence).lower() for sentence in translated_output]
tokenized_references = [[tokenizer.tokenize(sentence).lower()] for sentence in reference_translations]

# Step 4: Compute the BLEU score
bleu_score = corpus_bleu(tokenized_output, tokenized_references)
print("BLEU score:", bleu_score.score)
# Out:
# BLEU score: 3.7185675450147673
