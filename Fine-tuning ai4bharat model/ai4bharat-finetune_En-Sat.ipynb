# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory



# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Clone the github repository and navigate to the project directory.
# !git clone https://github.com/AI4Bharat/IndicTrans2
# %cd IndicTrans2/huggingface_interface

# Install all the dependencies and requirements associated with the project for running HF compatible models.
# !yes|source install.sh
# Out:
# Cloning into 'IndicTrans2'...
# remote: Enumerating objects: 738, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 738 (delta 138), reused 105 (delta 102), pack-reused 572 (from 1)
# Receiving objects: 100% (738/738), 4.14 MiB | 312.00 KiB/s, done.
# Resolving deltas: 100% (480/480), done.
# /home2/shivani.thakur/IndicTrans2/huggingface_interface
# Setting up the environment in the /home2/shivani.thakur/IndicTrans2/huggingface_interface
# Creating a virtual environment with python3
# Retrieving notices: ...working... done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home2/shivani.thakur/miniconda3/envs/itv2_hf
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.9.24  |       h06a4308_0         130 KB
#     ------------------------------------------------------------
#                                            Total:         130 KB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.9.24-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-3.0.15-h5eee18b_0
#   pip                pkgs/main/linux-64::pip-24.2-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.19-h955ad1f_1
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-75.1.0-py39h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   tzdata             pkgs/main/noarch::tzdata-2024a-h04d1e81_0
#   wheel              pkgs/main/linux-64::wheel-0.44.0-py39h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate itv2_hf
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CondaError: Run 'conda init' before 'conda activate'
#
# Installing all the dependencies
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home2/shivani.thakur/miniconda3/envs/ltrc
#
#   added / updated specs:
#     - pip
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2024.7.4~ --> pkgs/main::ca-certificates-2024.9.24-h06a4308_0
#
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Requirement already satisfied: pip in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (24.2)
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (2.4.1+cu118)
# Requirement already satisfied: filelock in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (72.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (11.8.86)
# Requirement already satisfied: triton==3.0.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sympy->torch) (1.3.0)
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home2/shivani.thakur/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: sentencepiece in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (0.2.0)
# Cloning into 'IndicTransToolkit'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 155 (delta 34), reused 45 (delta 30), pack-reused 95 (from 1)
# Receiving objects: 100% (155/155), 3.88 MiB | 348.00 KiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Obtaining file:///home2/shivani.thakur/IndicTrans2/huggingface_interface/IndicTransToolkit
#   Preparing metadata (setup.py) ... done
# Collecting indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library (from IndicTransToolkit==1.0.2)
#   Cloning https://github.com/VarunGumma/indic_nlp_library to /tmp/pip-install-al2ydxwe/indic-nlp-library-it2_72f9afc4b37a4d5096e1c71ccb980c53
#   Running command git clone --filter=blob:none --quiet https://github.com/VarunGumma/indic_nlp_library /tmp/pip-install-al2ydxwe/indic-nlp-library-it2_72f9afc4b37a4d5096e1c71ccb980c53
#   Resolved https://github.com/VarunGumma/indic_nlp_library to commit 601521e05ed0ed8f2165ac317a47d186e25b6f0d
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=68.2.2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from IndicTransToolkit==1.0.2) (72.1.0)
# Requirement already satisfied: torch in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from IndicTransToolkit==1.0.2) (2.4.1+cu118)
# Requirement already satisfied: sacremoses in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from IndicTransToolkit==1.0.2) (0.1.1)
# Requirement already satisfied: sentencepiece in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from IndicTransToolkit==1.0.2) (0.2.0)
# Requirement already satisfied: transformers in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from IndicTransToolkit==1.0.2) (4.44.2)
# Requirement already satisfied: sacrebleu in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from IndicTransToolkit==1.0.2) (2.4.3)
# Requirement already satisfied: sphinx-argparse in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (0.5.2)
# Requirement already satisfied: sphinx_rtd_theme in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: morfessor in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.6)
# Requirement already satisfied: pandas in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.2.2)
# Requirement already satisfied: numpy in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (1.26.4)
# Requirement already satisfied: portalocker in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sacrebleu->IndicTransToolkit==1.0.2) (2.10.1)
# Requirement already satisfied: regex in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sacrebleu->IndicTransToolkit==1.0.2) (2024.7.24)
# Requirement already satisfied: tabulate>=0.8.9 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sacrebleu->IndicTransToolkit==1.0.2) (0.9.0)
# Requirement already satisfied: colorama in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sacrebleu->IndicTransToolkit==1.0.2) (0.4.6)
# Requirement already satisfied: lxml in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sacrebleu->IndicTransToolkit==1.0.2) (5.3.0)
# Requirement already satisfied: click in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sacremoses->IndicTransToolkit==1.0.2) (8.1.7)
# Requirement already satisfied: joblib in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sacremoses->IndicTransToolkit==1.0.2) (1.4.2)
# Requirement already satisfied: tqdm in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sacremoses->IndicTransToolkit==1.0.2) (4.66.5)
# Requirement already satisfied: filelock in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (4.12.2)
# Requirement already satisfied: sympy in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (1.13.2)
# Requirement already satisfied: networkx in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (3.3)
# Requirement already satisfied: jinja2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (3.1.4)
# Requirement already satisfied: fsspec in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (11.8.86)
# Requirement already satisfied: triton==3.0.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch->IndicTransToolkit==1.0.2) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from transformers->IndicTransToolkit==1.0.2) (0.24.6)
# Requirement already satisfied: packaging>=20.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from transformers->IndicTransToolkit==1.0.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from transformers->IndicTransToolkit==1.0.2) (6.0.2)
# Requirement already satisfied: requests in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from transformers->IndicTransToolkit==1.0.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from transformers->IndicTransToolkit==1.0.2) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from transformers->IndicTransToolkit==1.0.2) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from jinja2->torch->IndicTransToolkit==1.0.2) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from requests->transformers->IndicTransToolkit==1.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from requests->transformers->IndicTransToolkit==1.0.2) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from requests->transformers->IndicTransToolkit==1.0.2) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from requests->transformers->IndicTransToolkit==1.0.2) (2024.8.30)
# Requirement already satisfied: sphinx>=5.1.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (7.4.7)
# Requirement already satisfied: docutils>=0.19 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (0.20.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx_rtd_theme->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (4.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sympy->torch->IndicTransToolkit==1.0.2) (1.3.0)
# Requirement already satisfied: six>=1.5 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: Pygments>=2.17 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.18.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.16.0)
# Requirement already satisfied: alabaster~=0.7.14 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (1.4.1)
# Installing collected packages: IndicTransToolkit
#   DEPRECATION: Legacy editable install of IndicTransToolkit==1.0.2 from file:///home2/shivani.thakur/IndicTrans2/huggingface_interface/IndicTransToolkit (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for IndicTransToolkit
# Successfully installed IndicTransToolkit-1.0.2
# Setup completed!
# yes: standard output: Broken pipe

# %%
# Define the path to the file
file_path = '/home2/shivani.thakur/IndicTrans2/huggingface_interface/train_lora.sh'

# Define the new content to write to the file
new_content = """
export CUDA_VISIBLE_DEVICES=0

data_dir=${1:-"en-indic-exp"}
model_name=${2:-"ai4bharat/indictrans2-en-indic-dist-200M"}
output_dir=${3:-"output"}
src_lang_list=${4:-"eng_Latn"}
tgt_lang_list=${5:-"sat_Olck"}

python3 train_lora.py \\
    --data_dir $data_dir \\
    --model_name $model_name \\
    --output_dir $output_dir \\
    --src_lang_list $src_lang_list \\
    --tgt_lang_list $tgt_lang_list \\
    --save_steps 1000 \\
    --max_steps 1000000 \\
    --batch_size 32 \\
    --grad_accum_steps 4 \\
    --warmup_steps 4000 \\
    --max_grad_norm 1.0 \\
    --learning_rate 2e-4 \\
    --adam_beta1 0.9 \\
    --adam_beta2 0.98 \\
    --optimizer adamw_torch \\
    --lr_scheduler inverse_sqrt \\
    --num_workers 16 \\
    --metric_for_best_model eval_BLEU \\
    --greater_is_better \\
    --patience 10 \\
    --weight_decay 0.01 \\
    --lora_target_modules "q_proj,k_proj" \\
    --lora_dropout 0.1 \\
    --lora_r 16 \\
    --lora_alpha 32 \\
    --print_samples
"""

# Open the file in write mode and replace the existing content
with open(file_path, 'w') as file:
    file.write(new_content)

print(f"File '{file_path}' has been updated with new content.")
# Out:
# File '/home2/shivani.thakur/IndicTrans2/huggingface_interface/train_lora.sh' has been updated with new content.

# %%
# Define the path to the file
file_path = '/home2/shivani.thakur/IndicTrans2/huggingface_interface/train_lora.sh'

# Open the file and read its contents
with open(file_path, 'r') as file:
    file_content = file.read()

# Print the contents of the file
print(file_content)
# Out:
# export CUDA_VISIBLE_DEVICES=0
#
# data_dir=${1:-"en-indic-exp"}
# model_name=${2:-"ai4bharat/indictrans2-en-indic-dist-200M"}
# output_dir=${3:-"output"}
# src_lang_list=${4:-"eng_Latn"}
# tgt_lang_list=${5:-"sat_Olck"}
#
# python3 train_lora.py \
#     --data_dir $data_dir \
#     --model_name $model_name \
#     --output_dir $output_dir \
#     --src_lang_list $src_lang_list \
#     --tgt_lang_list $tgt_lang_list \
#     --save_steps 1000 \
#     --max_steps 1000000 \
#     --batch_size 32 \
#     --grad_accum_steps 4 \
#     --warmup_steps 4000 \
#     --max_grad_norm 1.0 \
#     --learning_rate 2e-4 \
#     --adam_beta1 0.9 \
#     --adam_beta2 0.98 \
#     --optimizer adamw_torch \
#     --lr_scheduler inverse_sqrt \
#     --num_workers 16 \
#     --metric_for_best_model eval_BLEU \
#     --greater_is_better \
#     --patience 10 \
#     --weight_decay 0.01 \
#     --lora_target_modules "q_proj,k_proj" \
#     --lora_dropout 0.1 \
#     --lora_r 16 \
#     --lora_alpha 32 \
#     --print_samples

# %%
# Define the path to the file
file_path = '/home2/shivani.thakur/IndicTrans2/huggingface_interface/example.py'

# Read the existing content of the file
with open(file_path, 'r') as file:
    content = file.readlines()

# Open the file in write mode to update the content
with open(file_path, 'w') as file:
    for line in content:
        # Replace the specific mapping in the line
        line = line.replace('"sat_Olck": "or"', '"sat_Olck": "sat"')
        file.write(line)

print(f"Updated the mapping for 'sat_Olck' in '{file_path}'.")
# Out:
# Updated the mapping for 'sat_Olck' in '/home2/shivani.thakur/IndicTrans2/huggingface_interface/example.py'.

# %%
# Define the path to the file
file_path = '/home2/shivani.thakur/IndicTrans2/huggingface_interface/example.py'

# Open the file and read its contents
with open(file_path, 'r') as file:
    file_content = file.read()

# Print the contents of the file
print(file_content)
# Out:
# import sys
# import torch
# from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, BitsAndBytesConfig
# from transformers.utils import is_flash_attn_2_available, is_flash_attn_greater_or_equal_2_10
# from IndicTransToolkit import IndicProcessor
# from mosestokenizer import MosesSentenceSplitter
# from nltk import sent_tokenize
# from indicnlp.tokenize.sentence_tokenize import sentence_split, DELIM_PAT_NO_DANDA
#
#
# en_indic_ckpt_dir = "ai4bharat/indictrans2-en-indic-1B"  # ai4bharat/indictrans2-en-indic-dist-200M
# indic_en_ckpt_dir = "ai4bharat/indictrans2-indic-en-1B"  # ai4bharat/indictrans2-indic-en-dist-200M
# indic_indic_ckpt_dir = (
#     "ai4bharat/indictrans2-indic-indic-dist-320M"  # ai4bharat/indictrans2-indic-indic-dist-320M
# )
# BATCH_SIZE = 4
# DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
#
# if len(sys.argv) > 1:
#     quantization = sys.argv[1]
#     attn_implementation = sys.argv[2]
# else:
#     quantization = ""
#     attn_implementation = "eager"
#
#
# # FLORES language code mapping to 2 letter ISO language code for compatibility
# # with Indic NLP Library (https://github.com/anoopkunchukuttan/indic_nlp_library)
# flores_codes = {
#     "asm_Beng": "as",
#     "awa_Deva": "hi",
#     "ben_Beng": "bn",
#     "bho_Deva": "hi",
#     "brx_Deva": "hi",
#     "doi_Deva": "hi",
#     "eng_Latn": "en",
#     "gom_Deva": "kK",
#     "guj_Gujr": "gu",
#     "hin_Deva": "hi",
#     "hne_Deva": "hi",
#     "kan_Knda": "kn",
#     "kas_Arab": "ur",
#     "kas_Deva": "hi",
#     "kha_Latn": "en",
#     "lus_Latn": "en",
#     "mag_Deva": "hi",
#     "mai_Deva": "hi",
#     "mal_Mlym": "ml",
#     "mar_Deva": "mr",
#     "mni_Beng": "bn",
#     "mni_Mtei": "hi",
#     "npi_Deva": "ne",
#     "ory_Orya": "or",
#     "pan_Guru": "pa",
#     "san_Deva": "hi",
#     "sat_Olck": "sat",
#     "snd_Arab": "ur",
#     "snd_Deva": "hi",
#     "tam_Taml": "ta",
#     "tel_Telu": "te",
#     "urd_Arab": "ur",
# }
#
#
# def split_sentences(input_text, lang):
#     if lang == "eng_Latn":
#         input_sentences = sent_tokenize(input_text)
#         with MosesSentenceSplitter(flores_codes[lang]) as splitter:
#             sents_moses = splitter([input_text])
#         sents_nltk = sent_tokenize(input_text)
#         if len(sents_nltk) < len(sents_moses):
#             input_sentences = sents_nltk
#         else:
#             input_sentences = sents_moses
#         input_sentences = [sent.replace("\xad", "") for sent in input_sentences]
#     else:
#         input_sentences = sentence_split(
#             input_text, lang=flores_codes[lang], delim_pat=DELIM_PAT_NO_DANDA
#         )
#     return input_sentences
#
#
# def initialize_model_and_tokenizer(ckpt_dir, quantization, attn_implementation):
#     if quantization == "4-bit":
#         qconfig = BitsAndBytesConfig(
#             load_in_4bit=True,
#             bnb_4bit_use_double_quant=True,
#             bnb_4bit_compute_dtype=torch.bfloat16,
#         )
#     elif quantization == "8-bit":
#         qconfig = BitsAndBytesConfig(
#             load_in_8bit=True,
#             bnb_8bit_use_double_quant=True,
#             bnb_8bit_compute_dtype=torch.bfloat16,
#         )
#     else:
#         qconfig = None
#
#     if attn_implementation == "flash_attention_2":
#         if is_flash_attn_2_available() and is_flash_attn_greater_or_equal_2_10():
#             attn_implementation = "flash_attention_2"
#         else:
#             attn_implementation = "eager"
#
#     tokenizer = AutoTokenizer.from_pretrained(ckpt_dir, trust_remote_code=True)
#     model = AutoModelForSeq2SeqLM.from_pretrained(
#         ckpt_dir,
#         trust_remote_code=True,
#         attn_implementation=attn_implementation,
#         low_cpu_mem_usage=True,
#         quantization_config=qconfig,
#     )
#
#     if qconfig == None:
#         model = model.to(DEVICE)
#         model.half()
#
#     model.eval()
#
#     return tokenizer, model
#
#
# def batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip):
#     translations = []
#     for i in range(0, len(input_sentences), BATCH_SIZE):
#         batch = input_sentences[i : i + BATCH_SIZE]
#
#         # Preprocess the batch and extract entity mappings
#         batch = ip.preprocess_batch(batch, src_lang=src_lang, tgt_lang=tgt_lang)
#
#         # Tokenize the batch and generate input encodings
#         inputs = tokenizer(
#             batch,
#             truncation=True,
#             padding="longest",
#             return_tensors="pt",
#             return_attention_mask=True,
#         ).to(DEVICE)
#
#         # Generate translations using the model
#         with torch.no_grad():
#             generated_tokens = model.generate(
#                 **inputs,
#                 use_cache=True,
#                 min_length=0,
#                 max_length=256,
#                 num_beams=5,
#                 num_return_sequences=1,
#             )
#
#         # Decode the generated tokens into text
#         with tokenizer.as_target_tokenizer():
#             generated_tokens = tokenizer.batch_decode(
#                 generated_tokens.detach().cpu().tolist(),
#                 skip_special_tokens=True,
#                 clean_up_tokenization_spaces=True,
#             )
#
#         # Postprocess the translations, including entity replacement
#         translations += ip.postprocess_batch(generated_tokens, lang=tgt_lang)
#
#         del inputs
#         torch.cuda.empty_cache()
#
#     return translations
#
#
# def translate_paragraph(input_text, src_lang, tgt_lang, model, tokenizer, ip):
#     input_sentences = split_sentences(input_text, src_lang)
#     translated_text = batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip)
#     return " ".join(translated_text)
#
#
# ip = IndicProcessor(inference=True)
#
# en_indic_tokenizer, en_indic_model = initialize_model_and_tokenizer(
#     en_indic_ckpt_dir, quantization, attn_implementation
# )
#
# indic_en_tokenizer, indic_en_model = initialize_model_and_tokenizer(
#     indic_en_ckpt_dir, quantization, attn_implementation
# )
#
# indic_indic_tokenizer, indic_indic_model = initialize_model_and_tokenizer(
#     indic_indic_ckpt_dir, quantization, attn_implementation
# )
#
# # ---------------------------------------------------------------------------
# #                              Hindi to English
# # ---------------------------------------------------------------------------
# hi_sents = [
#     "जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।",
#     "उसके पास बहुत सारी पुरानी किताबें हैं, जिन्हें उसने अपने दादा-परदादा से विरासत में पाया।",
#     "मुझे समझ में नहीं आ रहा कि मैं अपनी समस्या का समाधान कैसे ढूंढूं।",
#     "वह बहुत मेहनती और समझदार है, इसलिए उसे सभी अच्छे मार्क्स मिले।",
#     "हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।",
#     "अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।",
#     "वह अपनी दीदी के साथ बाजार गयी थी ताकि वह नई साड़ी खरीद सके।",
#     "राज ने मुझसे कहा कि वह अगले महीने अपनी नानी के घर जा रहा है।",
#     "सभी बच्चे पार्टी में मज़ा कर रहे थे और खूब सारी मिठाइयाँ खा रहे थे।",
#     "मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।",
# ]
# src_lang, tgt_lang = "hin_Deva", "eng_Latn"
# en_translations = batch_translate(
#     hi_sents, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip
# )
#
# print(f"\n{src_lang} - {tgt_lang}")
# for input_sentence, translation in zip(hi_sents, en_translations):
#     print(f"{src_lang}: {input_sentence}")
#     print(f"{tgt_lang}: {translation}")
#
#
# # ---------------------------------------------------------------------------
# #                              English to Hindi
# # ---------------------------------------------------------------------------
# en_sents = [
#     "When I was young, I used to go to the park every day.",
#     "He has many old books, which he inherited from his ancestors.",
#     "I can't figure out how to solve my problem.",
#     "She is very hardworking and intelligent, which is why she got all the good marks.",
#     "We watched a new movie last week, which was very inspiring.",
#     "If you had met me at that time, we would have gone out to eat.",
#     "She went to the market with her sister to buy a new sari.",
#     "Raj told me that he is going to his grandmother's house next month.",
#     "All the kids were having fun at the party and were eating lots of sweets.",
#     "My friend has invited me to his birthday party, and I will give him a gift.",
# ]
# src_lang, tgt_lang = "eng_Latn", "hin_Deva"
# hi_translations = batch_translate(
#     en_sents, src_lang, tgt_lang, en_indic_model, en_indic_tokenizer, ip
# )
#
# print(f"\n{src_lang} - {tgt_lang}")
# for input_sentence, translation in zip(en_sents, hi_translations):
#     print(f"{src_lang}: {input_sentence}")
#     print(f"{tgt_lang}: {translation}")
#
#
# # ---------------------------------------------------------------------------
# #                              Hindi to Marathi
# # ---------------------------------------------------------------------------
# hi_sents = [
#     "जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।",
#     "उसके पास बहुत सारी पुरानी किताबें हैं, जिन्हें उसने अपने दादा-परदादा से विरासत में पाया।",
#     "मुझे समझ में नहीं आ रहा कि मैं अपनी समस्या का समाधान कैसे ढूंढूं।",
#     "वह बहुत मेहनती और समझदार है, इसलिए उसे सभी अच्छे मार्क्स मिले।",
#     "हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।",
#     "अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।",
#     "वह अपनी दीदी के साथ बाजार गयी थी ताकि वह नई साड़ी खरीद सके।",
#     "राज ने मुझसे कहा कि वह अगले महीने अपनी नानी के घर जा रहा है।",
#     "सभी बच्चे पार्टी में मज़ा कर रहे थे और खूब सारी मिठाइयाँ खा रहे थे।",
#     "मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।",
# ]
# src_lang, tgt_lang = "hin_Deva", "mar_Deva"
# mr_translations = batch_translate(
#     hi_sents, src_lang, tgt_lang, indic_indic_model, indic_indic_tokenizer, ip
# )
#
# print(f"\n{src_lang} - {tgt_lang}")
# for input_sentence, translation in zip(hi_sents, mr_translations):
#     print(f"{src_lang}: {input_sentence}")
#     print(f"{tgt_lang}: {translation}")
#
#
# # ---------------------------------------------------------------------------
# #                             Paragraph translation
# # ---------------------------------------------------------------------------
# src_lang, tgt_lang = "hin_Deva", "eng_Latn"
# hi_text = "यहाँ एक पाराग्राफ है जो हिंदी में लिखा गया है। हिंदी एक सुंदर भाषा है और भारत की राष्ट्रीय भाषा है। इसका विकास विभिन्न कालों में हुआ है और यह विशेषतः भारतीय उपमहाद्वीप में बोली जाती है। हिंदी भाषा का साहित्य, संस्कृति और इतिहास भी बहुत गर्वनीय है।"
# en_translated_text = translate_paragraph(
#     hi_text, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip
# )
# print(f"{src_lang}: {hi_text}")
# print(f"{tgt_lang}: {en_translated_text}")

# %%
# !pip install peft
# Out:
# Requirement already satisfied: peft in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (5.9.0)
# Requirement already satisfied: pyyaml in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (2.4.1+cu118)
# Requirement already satisfied: transformers in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (4.44.2)
# Requirement already satisfied: tqdm in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (4.66.5)
# Requirement already satisfied: accelerate>=0.21.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (0.34.2)
# Requirement already satisfied: safetensors in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from peft) (0.24.6)
# Requirement already satisfied: filelock in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from huggingface-hub>=0.17.0->peft) (3.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from huggingface-hub>=0.17.0->peft) (2024.6.1)
# Requirement already satisfied: requests in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: sympy in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (1.13.2)
# Requirement already satisfied: networkx in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: setuptools in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (72.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.8.86)
# Requirement already satisfied: triton==3.0.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from transformers->peft) (2024.7.24)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)

# %%
# Define the path to the file
file_path = '/home2/shivani.thakur/IndicTrans2/huggingface_interface/train_lora.py'

# Define the new content to write to the file
new_content = """
import os
import argparse
import pandas as pd
from datasets import Dataset
from sacrebleu.metrics import BLEU, CHRF
from peft import LoraConfig, get_peft_model
from IndicTransToolkit import IndicProcessor, IndicDataCollator

from transformers import (
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    EarlyStoppingCallback,
)

bleu_metric = BLEU()
chrf_metric = CHRF()


def get_arg_parse():
    parser = argparse.ArgumentParser()
    parser.add_argument(
        "--model_name",
        type=str,
    )
    parser.add_argument(
        "--src_lang_list",
        type=str,
        help="comma separated list of source languages",
    )
    parser.add_argument(
        "--tgt_lang_list",
        type=str,
        help="comma separated list of target languages",
    )
    parser.add_argument("--data_dir", type=str)
    parser.add_argument("--output_dir", type=str)
    parser.add_argument("--save_steps", type=int, default=1000)
    parser.add_argument("--eval_steps", type=int, default=1000)
    parser.add_argument("--batch_size", type=int, default=32)
    parser.add_argument("--num_train_epochs", type=int, default=100)
    parser.add_argument("--max_steps", type=int, default=1000000)
    parser.add_argument("--grad_accum_steps", type=int, default=4)
    parser.add_argument("--warmup_steps", type=int, default=4000)
    parser.add_argument("--warmup_ratio", type=int, default=0.0)
    parser.add_argument("--max_grad_norm", type=float, default=1.0)
    parser.add_argument("--learning_rate", type=float, default=5e-4)
    parser.add_argument("--weight_decay", type=float, default=0.0)
    parser.add_argument("--adam_beta1", type=float, default=0.9)
    parser.add_argument("--adam_beta2", type=float, default=0.98)
    parser.add_argument("--dropout", type=float, default=0.0)
    parser.add_argument("--print_samples", action="store_true")
    parser.add_argument(
        "--optimizer",
        type=str,
        default="adamw_torch",
        choices=[
            "adam_hf",
            "adamw_torch",
            "adamw_torch_fused",
            "adamw_apex_fused",
            "adafactor",
        ],
    )
    parser.add_argument(
        "--lr_scheduler",
        type=str,
        default="inverse_sqrt",
        choices=[
            "inverse_sqrt",
            "linear",
            "polynomial",
            "cosine",
            "constant",
            "constant_with_warmup",
        ],
    )
    parser.add_argument("--label_smoothing", type=float, default=0.0)
    parser.add_argument("--num_workers", type=int, default=8)
    parser.add_argument("--metric_for_best_model", type=str, default="eval_loss")
    parser.add_argument("--greater_is_better", action="store_true")
    parser.add_argument("--lora_target_modules", type=str, default="q_proj,k_proj")
    parser.add_argument("--lora_dropout", type=float, default=0.1)
    parser.add_argument("--lora_r", type=int, default=16)
    parser.add_argument("--lora_alpha", type=int, default=32)
    parser.add_argument(
        "--report_to",
        type=str,
        default="none",
        choices=["wandb", "tensorboard", "azure_ml", "none"],
    )
    parser.add_argument("--patience", type=int, default=5),
    parser.add_argument("--threshold", type=float, default=1e-3)
    return parser


def load_and_process_translation_dataset(
    data_dir,
    split="train",
    tokenizer=None,
    processor=None,
    src_lang_list=None,
    tgt_lang_list=None,
    num_proc=8,
    seed=42
):
    complete_dataset = {
        "sentence_SRC": [],
        "sentence_TGT": [],
    }

    for src_lang in src_lang_list:
        for tgt_lang in tgt_lang_list:
            if src_lang == tgt_lang:
                continue
            src_path = os.path.join(
                data_dir, split, f"{src_lang}-{tgt_lang}", f"{split}.{src_lang}"
            )
            tgt_path = os.path.join(
                data_dir, split, f"{src_lang}-{tgt_lang}", f"{split}.{tgt_lang}"
            )
            if not os.path.exists(src_path) or not os.path.exists(tgt_path):
                raise FileNotFoundError(
                    f"Source ({split}.{src_lang}) or Target ({split}.{tgt_lang}) file not found in {data_dir}"
                )
            with open(src_path, encoding="utf-8") as src_file, open(
                tgt_path, encoding="utf-8"
            ) as tgt_file:
                src_lines = src_file.readlines()
                tgt_lines = tgt_file.readlines()

            # Ensure both files have the same number of lines
            assert len(src_lines) == len(
                tgt_lines
            ), f"Source and Target files have different number of lines for {split}.{src_lang} and {split}.{tgt_lang}"

            complete_dataset["sentence_SRC"] += processor.preprocess_batch(
                src_lines, src_lang=src_lang, tgt_lang=tgt_lang, is_target=False
            )

            complete_dataset["sentence_TGT"] += processor.preprocess_batch(
                tgt_lines, src_lang=tgt_lang, tgt_lang=src_lang, is_target=True
            )

    complete_dataset = Dataset.from_dict(complete_dataset).shuffle(seed=seed)

    return complete_dataset.map(
        lambda example: preprocess_fn(
            example,
            tokenizer=tokenizer
        ),
        batched=True,
        num_proc=num_proc,
    )


def compute_metrics_factory(
    tokenizer, metric_dict=None, print_samples=False, n_samples=10
):
    def compute_metrics(eval_preds):
        preds, labels = eval_preds

        labels[labels == -100] = tokenizer.pad_token_id
        preds[preds == -100] = tokenizer.pad_token_id

        with tokenizer.as_target_tokenizer():
            preds = [
                x.strip()
                for x in tokenizer.batch_decode(
                    preds, skip_special_tokens=True, clean_up_tokenization_spaces=True
                )
            ]
            labels = [
                x.strip()
                for x in tokenizer.batch_decode(
                    labels, skip_special_tokens=True, clean_up_tokenization_spaces=True
                )
            ]

        assert len(preds) == len(
            labels
        ), "Predictions and Labels have different lengths"

        df = pd.DataFrame({"Predictions": preds, "References": labels}).sample(
            n=n_samples
        )

        if print_samples:
            for pred, label in zip(df["Predictions"].values, df["References"].values):
                print(f" | > Prediction: {pred}")
                print(f" | > Reference: {label}\\n")

        return {
            metric_name: metric.corpus_score(preds, [labels]).score
            for (metric_name, metric) in metric_dict.items()
        }

    return compute_metrics


def preprocess_fn(example, tokenizer, **kwargs):
    model_inputs = tokenizer(
        example["sentence_SRC"], truncation=True, padding=False, max_length=256
    )

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            example["sentence_TGT"], truncation=True, padding=False, max_length=256
        )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs


def main(args):
    print(f" | > Loading {args.model_name} and tokenizer ...")
    model = AutoModelForSeq2SeqLM.from_pretrained(
        args.model_name,
        trust_remote_code=True,
        attn_implementation="eager",
        dropout=args.dropout
    )

    tokenizer = AutoTokenizer.from_pretrained(args.model_name, trust_remote_code=True)
    processor = IndicProcessor(inference=False) # pre-process before tokenization
    
    data_collator = IndicDataCollator(
        tokenizer=tokenizer,
        model=model,
        padding="longest", # saves padding tokens
        pad_to_multiple_of=8, # better to have it as 8 when using fp16
        label_pad_token_id=-100
    )

    if args.data_dir is not None:
        train_dataset = load_and_process_translation_dataset(
            args.data_dir,
            split="train",
            tokenizer=tokenizer,
            processor=processor,
            src_lang_list=args.src_lang_list.split(","),
            tgt_lang_list=args.tgt_lang_list.split(","),
        )
        print(f" | > Loaded train dataset from {args.data_dir}. Size: {len(train_dataset)} ...")

        eval_dataset = load_and_process_translation_dataset(
            args.data_dir,
            split="dev",
            tokenizer=tokenizer,
            processor=processor,
            src_lang_list=args.src_lang_list.split(","),
            tgt_lang_list=args.tgt_lang_list.split(","),
        )
        print(f" | > Loaded eval dataset from {args.data_dir}. Size: {len(eval_dataset)} ...")
    else:
        raise ValueError(" | > Data directory not provided")

    lora_config = LoraConfig(
        r=args.lora_r,
        bias="none",
        inference_mode=False,
        task_type="SEQ_2_SEQ_LM",
        lora_alpha=args.lora_alpha,
        lora_dropout=args.lora_dropout,
        target_modules=args.lora_target_modules.split(","),
    )

    model.set_label_smoothing(args.label_smoothing)

    model = get_peft_model(model, lora_config)
    model.print_trainable_parameters()

    print(f" | > Loading metrics factory with BLEU and chrF ...")
    seq2seq_compute_metrics = compute_metrics_factory(
        tokenizer=tokenizer,
        print_samples=args.print_samples,
        metric_dict={"BLEU": bleu_metric, "chrF": chrf_metric},
    )

    training_args = Seq2SeqTrainingArguments(
        output_dir=args.output_dir,
        do_train=True,
        do_eval=True,
        fp16=True, # use fp16 for faster training
        logging_strategy="steps",
        evaluation_strategy="steps",
        save_strategy="steps",
        logging_steps=100,
        save_total_limit=1,
        predict_with_generate=True,
        load_best_model_at_end=True,
        max_steps=args.max_steps, # max_steps overrides num_train_epochs
        per_device_train_batch_size=args.batch_size,
        per_device_eval_batch_size=args.batch_size,
        gradient_accumulation_steps=args.grad_accum_steps,
        eval_accumulation_steps=args.grad_accum_steps,
        weight_decay=args.weight_decay,
        adam_beta1=args.adam_beta1,
        adam_beta2=args.adam_beta2,
        max_grad_norm=args.max_grad_norm,
        optim=args.optimizer,
        lr_scheduler_type=args.lr_scheduler,
        warmup_ratio=args.warmup_ratio,
        warmup_steps=args.warmup_steps,
        learning_rate=args.learning_rate,
        num_train_epochs=args.num_train_epochs,
        save_steps=args.save_steps,
        eval_steps=args.eval_steps,
        dataloader_num_workers=args.num_workers,
        metric_for_best_model=args.metric_for_best_model,
        greater_is_better=args.greater_is_better,
        report_to=args.report_to,
        generation_max_length=256,
        generation_num_beams=5,
        sortish_sampler=True,
        group_by_length=True,
        include_tokens_per_second=True,
        include_num_input_tokens_seen=True,
        dataloader_prefetch_factor=2,
    )

    # Create Trainer instance
    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        data_collator=data_collator,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        compute_metrics=seq2seq_compute_metrics,
        callbacks=[
            EarlyStoppingCallback(
                early_stopping_patience=args.patience,
                early_stopping_threshold=args.threshold,
            )
        ],
    )

    print(f" | > Starting training ...")

    try:
        trainer.train()
    except KeyboardInterrupt:
        print(f" | > Training interrupted ...")

    # this will only save the LoRA adapter weights
    model.save_pretrained(args.output_dir)



if __name__ == "__main__":
    parser = get_arg_parse()
    args = parser.parse_args()

    main(args)
"""

# Open the file in write mode and replace the existing content
with open(file_path, 'w') as file:
    file.write(new_content)

print(f"File '{file_path}' has been updated with new content.")
# Out:
# File '/home2/shivani.thakur/IndicTrans2/huggingface_interface/train_lora.py' has been updated with new content.

# %%
# !bash train_lora.sh /home2/shivani.thakur/en-santali-exp/en-santali-exp ai4bharat/indictrans2-en-indic-dist-200M /home2/shivani.thakur/output eng_Latn sat_Olck
# Out:
#  | > Loading ai4bharat/indictrans2-en-indic-dist-200M and tokenizer ...
# Map (num_proc=8):   0%|                       | 0/207688 [00:00<?, ? examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):   2%|▏         | 4000/207688 [00:02<01:32, 2198.60 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):   9%|▋       | 19000/207688 [00:03<00:16, 11569.16 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  16%|█▎      | 34000/207688 [00:04<00:10, 15974.29 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  29%|██▎     | 60961/207688 [00:05<00:07, 20818.81 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  39%|███▏    | 81922/207688 [00:06<00:05, 22111.40 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  54%|███▊   | 112922/207688 [00:08<00:04, 21512.62 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  66%|████▌  | 136844/207688 [00:09<00:02, 23861.51 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8): 100%|███████| 207688/207688 [00:13<00:00, 15366.79 examples/s]
#  | > Loaded train dataset from /home2/shivani.thakur/en-santali-exp/en-santali-exp. Size: 207688 ...
# Map (num_proc=8):   0%|                        | 0/51922 [00:00<?, ? examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  12%|█▎         | 6000/51922 [00:02<00:09, 4781.68 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  24%|██▍       | 12491/51922 [00:02<00:05, 6769.62 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  35%|███▍      | 17982/51922 [00:03<00:05, 6267.43 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  49%|████▉     | 25472/51922 [00:04<00:03, 7172.01 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  62%|██████▏   | 31962/51922 [00:05<00:02, 7035.48 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  74%|███████▍  | 38452/51922 [00:06<00:01, 7010.08 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8):  87%|████████▋ | 44942/51922 [00:07<00:00, 7268.09 examples/s]/home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map (num_proc=8): 100%|██████████| 51922/51922 [00:08<00:00, 6141.85 examples/s]
#  | > Loaded eval dataset from /home2/shivani.thakur/en-santali-exp/en-santali-exp. Size: 51922 ...
# trainable params: 1,769,472 || all params: 276,354,048 || trainable%: 0.6403
#  | > Loading metrics factory with BLEU and chrF ...
# /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# Detected kernel version 4.15.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# max_steps is given, it will override any value given in num_train_epochs
#  | > Starting training ...
# /home2/shivani.thakur/miniconda3/envs/ltrc/lib/python3.12/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 10, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# {'loss': 2.934, 'grad_norm': 3.4765655994415283, 'learning_rate': 5e-06, 'epoch': 0.02, 'num_input_tokens_seen': 52352}
# {'loss': 2.7445, 'grad_norm': 1.7220431566238403, 'learning_rate': 1e-05, 'epoch': 0.03, 'num_input_tokens_seen': 102976}
# {'loss': 2.4822, 'grad_norm': 0.3161921501159668, 'learning_rate': 1.5e-05, 'epoch': 0.05, 'num_input_tokens_seen': 154624}
# {'loss': 2.3473, 'grad_norm': 0.1908281147480011, 'learning_rate': 2e-05, 'epoch': 0.06, 'num_input_tokens_seen': 205952}
# {'loss': 2.319, 'grad_norm': 0.1131175234913826, 'learning_rate': 2.5e-05, 'epoch': 0.08, 'num_input_tokens_seen': 257216}
# {'loss': 2.2946, 'grad_norm': 0.05646347254514694, 'learning_rate': 3e-05, 'epoch': 0.09, 'num_input_tokens_seen': 307328}
# {'loss': 2.281, 'grad_norm': 0.03339526802301407, 'learning_rate': 3.5e-05, 'epoch': 0.11, 'num_input_tokens_seen': 359232}
# {'loss': 2.2183, 'grad_norm': 0.02306072786450386, 'learning_rate': 4e-05, 'epoch': 0.12, 'num_input_tokens_seen': 411072}
# {'loss': 2.1763, 'grad_norm': 0.021064916625618935, 'learning_rate': 4.5e-05, 'epoch': 0.14, 'num_input_tokens_seen': 463104}
# {'loss': 2.2701, 'grad_norm': 0.025276239961385727, 'learning_rate': 5e-05, 'epoch': 0.15, 'num_input_tokens_seen': 514944}
#   0%|                                | 1000/1000000 [12:02<192:08:49,  1.44it/s]
#   0%|                                                  | 0/6491 [00:00<?, ?it/s]
#   0%|                                        | 2/6491 [00:08<7:49:00,  4.34s/it]
#   0%|                                       | 3/6491 [00:17<11:22:08,  6.31s/it]
#   0%|                                       | 4/6491 [00:26<13:07:42,  7.29s/it]
#   0%|                                       | 5/6491 [00:37<15:29:00,  8.59s/it]
#   0%|                                       | 6/6491 [00:46<15:36:29,  8.66s/it]
#   0%|                                       | 7/6491 [00:55<15:47:12,  8.77s/it]
#   0%|                                       | 8/6491 [01:04<15:55:24,  8.84s/it]
#   0%|                                       | 9/6491 [01:13<16:12:43,  9.00s/it]
#   0%|                                      | 10/6491 [01:23<16:22:14,  9.09s/it]
#   0%|                                      | 11/6491 [01:32<16:14:18,  9.02s/it]
#   0%|                                      | 12/6491 [01:41<16:18:28,  9.06s/it]
#   0%|                                      | 13/6491 [01:50<16:26:26,  9.14s/it]
#   0%|                                      | 14/6491 [01:59<16:25:57,  9.13s/it]
#   0%|                                      | 15/6491 [02:08<16:23:53,  9.12s/it]
#   0%|                                      | 16/6491 [02:18<16:31:51,  9.19s/it]
#   0%|                                      | 17/6491 [02:27<16:43:27,  9.30s/it]
#   0%|                                      | 18/6491 [02:36<16:25:56,  9.14s/it]
#  26%|████████▊                         | 1685/6491 [4:18:36<12:29:21,  9.36s/it]
#  26%|████████▊                         | 1686/6491 [4:18:45<12:22:48,  9.28s/it]
#  26%|████████▊                         | 1687/6491 [4:18:54<12:26:51,  9.33s/it]
#  26%|████████▊                         | 1688/6491 [4:19:04<12:31:12,  9.38s/it]
#  26%|████████▊                         | 1689/6491 [4:19:13<12:33:24,  9.41s/it]
#  26%|████████▊                         | 1690/6491 [4:19:22<12:16:31,  9.20s/it]
#  26%|████████▊                         | 1691/6491 [4:19:31<12:22:59,  9.29s/it]
#  26%|████████▊                         | 1692/6491 [4:19:40<12:13:38,  9.17s/it]
#  26%|████████▊                         | 1693/6491 [4:19:51<12:50:23,  9.63s/it]
#  26%|████████▊                         | 1694/6491 [4:20:01<12:53:35,  9.68s/it]
#  26%|████████▉                         | 1695/6491 [4:20:10<12:36:18,  9.46s/it]
#  26%|████████▉                         | 1696/6491 [4:20:19<12:30:39,  9.39s/it]
#  26%|████████▉                         | 1697/6491 [4:20:29<12:38:48,  9.50s/it]
#  26%|████████▉                         | 1698/6491 [4:20:38<12:29:58,  9.39s/it]
#  26%|████████▉                         | 1699/6491 [4:20:47<12:22:27,  9.30s/it]
#  26%|████████▉                         | 1700/6491 [4:20:56<12:10:23,  9.15s/it]
#  26%|████████▉                         | 1701/6491 [4:21:05<12:26:38,  9.35s/it]
#  26%|████████▉                         | 1702/6491 [4:21:15<12:24:38,  9.33s/it]
#  26%|████████▉                         | 1703/6491 [4:21:24<12:28:53,  9.38s/it]
#  26%|████████▉                         | 1704/6491 [4:21:34<12:32:33,  9.43s/it]
#  26%|████████▉                         | 1705/6491 [4:21:43<12:25:27,  9.35s/it]
#  26%|████████▉                         | 1706/6491 [4:21:52<12:18:07,  9.26s/it]
#  26%|████████▉                         | 1707/6491 [4:22:01<12:08:59,  9.14s/it]
#  26%|████████▉                         | 1708/6491 [4:22:10<12:09:37,  9.15s/it]
#  26%|████████▉                         | 1709/6491 [4:22:19<12:13:41,  9.21s/it]
#  26%|████████▉                         | 1710/6491 [4:22:28<12:01:50,  9.06s/it]
#  26%|████████▉                         | 1711/6491 [4:22:37<12:04:40,  9.10s/it]
#  26%|████████▉                         | 1712/6491 [4:22:46<12:03:59,  9.09s/it]
#  26%|████████▉                         | 1713/6491 [4:22:56<12:07:04,  9.13s/it]
#  26%|████████▉                         | 1714/6491 [4:23:04<11:56:58,  9.01s/it]
#  26%|████████▉                         | 1715/6491 [4:23:14<12:06:34,  9.13s/it]
#  26%|████████▉                         | 1716/6491 [4:23:23<12:13:34,  9.22s/it]^C
#  | > Training interrupted ...

# %%
# Define the path to the file
file_path = '/kaggle/working/IndicTrans2/huggingface_interface/train_lora.py'

# Open the file and read its contents
with open(file_path, 'r') as file:
    file_content = file.read()

# Print the contents of the file
print(file_content)
# Out:
# import os
# import argparse
# import pandas as pd
# from datasets import Dataset
# from sacrebleu.metrics import BLEU, CHRF
# from peft import LoraConfig, get_peft_model
# from IndicTransTokenizer import IndicProcessor, IndicDataCollator
# from transformers import (
#     Seq2SeqTrainer,
#     Seq2SeqTrainingArguments,
#     AutoModelForSeq2SeqLM,
#     AutoTokenizer,
#     EarlyStoppingCallback,
# )
#
# bleu_metric = BLEU()
# chrf_metric = CHRF()
#
# def get_arg_parse():
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--model", type=str)
#     parser.add_argument("--src_lang_list", type=str, help="comma separated list of source languages")
#     parser.add_argument("--tgt_lang_list", type=str, help="comma separated list of target languages")
#     parser.add_argument("--data_dir", type=str)
#     parser.add_argument("--output_dir", type=str)
#     parser.add_argument("--save_steps", type=int, default=1000)
#     parser.add_argument("--eval_steps", type=int, default=1000)
#     parser.add_argument("--batch_size", type=int, default=32)
#     parser.add_argument("--num_train_epochs", type=int, default=100)
#     parser.add_argument("--max_steps", type=int, default=1000000)
#     parser.add_argument("--grad_accum_steps", type=int, default=4)
#     parser.add_argument("--warmup_steps", type=int, default=4000)
#     parser.add_argument("--warmup_ratio", type=float, default=0.0)
#     parser.add_argument("--max_grad_norm", type=float, default=1.0)
#     parser.add_argument("--learning_rate", type=float, default=5e-4)
#     parser.add_argument("--weight_decay", type=float, default=0.0)
#     parser.add_argument("--adam_beta1", type=float, default=0.9)
#     parser.add_argument("--adam_beta2", type=float, default=0.98)
#     parser.add_argument("--dropout", type=float, default=0.0)
#     parser.add_argument("--print_samples", action="store_true")
#     parser.add_argument("--optimizer", type=str, default="adamw_torch", choices=["adam_hf", "adamw_torch", "adamw_torch_fused", "adamw_apex_fused", "adafactor"])
#     parser.add_argument("--lr_scheduler", type=str, default="inverse_sqrt", choices=["inverse_sqrt", "linear", "polynomial", "cosine", "constant", "constant_with_warmup"])
#     parser.add_argument("--label_smoothing", type=float, default=0.0)
#     parser.add_argument("--num_workers", type=int, default=8)
#     parser.add_argument("--metric_for_best_model", type=str, default="eval_loss")
#     parser.add_argument("--greater_is_better", action="store_true")
#     parser.add_argument("--lora_target_modules", type=str, default="q_proj,k_proj")
#     parser.add_argument("--lora_dropout", type=float, default=0.1)
#     parser.add_argument("--lora_r", type=int, default=16)
#     parser.add_argument("--lora_alpha", type=int, default=32)
#     parser.add_argument("--report_to", type=str, default="none", choices=["wandb", "tensorboard", "azure_ml", "none"])
#     parser.add_argument("--patience", type=int, default=5)
#     parser.add_argument("--threshold", type=float, default=1e-3)
#     return parser
#
# def load_and_process_translation_dataset(data_dir, split="train", tokenizer=None, processor=None, src_lang_list=None, tgt_lang_list=None, num_proc=8, seed=42):
#     complete_dataset = {
#         "sentence_SRC": [],
#         "sentence_TGT": [],
#     }
#
#     for src_lang in src_lang_list:
#         for tgt_lang in tgt_lang_list:
#             if src_lang == tgt_lang:
#                 continue
#             src_path = os.path.join(data_dir, split, f"{src_lang}-{tgt_lang}", f"{split}.{src_lang}")
#             tgt_path = os.path.join(data_dir, split, f"{src_lang}-{tgt_lang}", f"{split}.{tgt_lang}")
#             if not os.path.exists(src_path) or not os.path.exists(tgt_path):
#                 raise FileNotFoundError(f"Source ({split}.{src_lang}) or Target ({split}.{tgt_lang}) file not found in {data_dir}")
#             with open(src_path, encoding="utf-8") as src_file, open(tgt_path, encoding="utf-8") as tgt_file:
#                 src_lines = src_file.readlines()
#                 tgt_lines = tgt_file.readlines()
#
#             # Ensure both files have the same number of lines
#             assert len(src_lines) == len(tgt_lines), f"Source and Target files have different number of lines for {split}.{src_lang} and {split}.{tgt_lang}"
#
#             complete_dataset["sentence_SRC"] += processor.preprocess_batch(src_lines, src_lang=src_lang, tgt_lang=tgt_lang, is_target=False)
#             complete_dataset["sentence_TGT"] += processor.preprocess_batch(tgt_lines, src_lang=tgt_lang, tgt_lang=src_lang, is_target=True)
#
#     complete_dataset = Dataset.from_dict(complete_dataset).shuffle(seed=seed)
#
#     return complete_dataset.map(lambda example: preprocess_fn(example, tokenizer=tokenizer), batched=True, num_proc=num_proc)
#
# def compute_metrics_factory(tokenizer, metric_dict=None, print_samples=False, n_samples=10):
#     def compute_metrics(eval_preds):
#         preds, labels = eval_preds
#
#         labels[labels == -100] = tokenizer.pad_token_id
#         preds[preds == -100] = tokenizer.pad_token_id
#
#         with tokenizer.as_target_tokenizer():
#             preds = [x.strip() for x in tokenizer.batch_decode(preds, skip_special_tokens=True, clean_up_tokenization_spaces=True)]
#             labels = [x.strip() for x in tokenizer.batch_decode(labels, skip_special_tokens=True, clean_up_tokenization_spaces=True)]
#
#         assert len(preds) == len(labels), "Predictions and Labels have different lengths"
#
#         df = pd.DataFrame({"Predictions": preds, "References": labels}).sample(n=n_samples)
#
#         if print_samples:
#             for pred, label in zip(df["Predictions"].values, df["References"].values):
#                 print(f" | > Prediction: {pred}")
#                 print(f" | > Reference: {label}\n")
#
#         return {
#             metric_name: metric.corpus_score(preds, [labels]).score
#             for (metric_name, metric) in metric_dict.items()
#         }
#
#     return compute_metrics
#
# def preprocess_fn(example, tokenizer, **kwargs):
#     model_inputs = tokenizer(example["sentence_SRC"], truncation=True, padding=False, max_length=256)
#
#     with tokenizer.as_target_tokenizer():
#         labels = tokenizer(example["sentence_TGT"], truncation=True, padding=False, max_length=256)
#
#     model_inputs["labels"] = labels["input_ids"]
#     return model_inputs
#
# def main(args):
#     print(f" | > Loading {args.model} and tokenizer ...")
#     model = AutoModelForSeq2SeqLM.from_pretrained(args.model, trust_remote_code=True, attn_implementation="eager", dropout=args.dropout)
#
#     tokenizer = AutoTokenizer.from_pretrained(args.model, trust_remote_code=True)
#     processor = IndicProcessor(inference=False)  # pre-process before tokenization
#
#     data_collator = IndicDataCollator(
#         tokenizer=tokenizer,
#         model=model,
#         padding="longest",  # saves padding tokens
#         pad_to_multiple_of=8,  # better to have it as 8 when using fp16
#         label_pad_token_id=-100
#     )
#
#     if args.data_dir is not None:
#         train_dataset = load_and_process_translation_dataset(
#             args.data_dir,
#             split="train",
#             tokenizer=tokenizer,
#             processor=processor,
#             src_lang_list=args.src_lang_list.split(","),
#             tgt_lang_list=args.tgt_lang_list.split(","),
#         )
#         print(f" | > Loaded train dataset from {args.data_dir}. Size: {len(train_dataset)} ...")
#
#         eval_dataset = load_and_process_translation_dataset(
#             args.data_dir,
#             split="dev",
#             tokenizer=tokenizer,
#             processor=processor,
#             src_lang_list=args.src_lang_list.split(","),
#             tgt_lang_list=args.tgt_lang_list.split(","),
#         )
#         print(f" | > Loaded eval dataset from {args.data_dir}. Size: {len(eval_dataset)} ...")
#     else:
#         raise ValueError(" | > Data directory not provided")
#
#     lora_config = LoraConfig(
#         r=args.lora_r,
#         bias="none",
#         inference_mode=False,
#         task_type="SEQ_2_SEQ_LM",
#         lora_alpha=args.lora_alpha,
#         lora_dropout=args.lora_dropout,
#         target_modules=args.lora_target_modules.split(","),
#     )
#
#     model.set_label_smoothing(args.label_smoothing)
#
#     model = get_peft_model(model, lora_config)
#     model.print_trainable_parameters()
#
#     print(f" | > Loading metrics factory with BLEU and chrF ...")
#     seq2seq_compute_metrics = compute_metrics_factory(
#         tokenizer=tokenizer,
#         print_samples=args.print_samples,
#         metric_dict={"BLEU": bleu_metric, "chrF": chrf_metric},
#     )
#
#     training_args = Seq2SeqTrainingArguments(
#         output_dir=args.output_dir,
#         do_train=True,
#         do_eval=True,
#         fp16=True,  # use fp16 for faster training
#         logging_strategy="steps",
#         evaluation_strategy="steps",
#         save_strategy="steps",
#         logging_steps=100,
#         save_total_limit=1,
#         predict_with_generate=True,
#         load_best_model_at_end=True,
#         max_steps=args.max_steps,  # max_steps overrides num_train_epochs
#         per_device_train_batch_size=args.batch_size,
#         per_device_eval_batch_size=args.batch_size,
#         gradient_accumulation_steps=args.grad_accum_steps,
#         eval_accumulation_steps=args.grad_accum_steps,
#         weight_decay=args.weight_decay,
#         adam_beta1=args.adam_beta1,
#         adam_beta2=args.adam_beta2,
#         max_grad_norm=args.max_grad_norm,
#         optim=args.optimizer,
#         lr_scheduler_type=args.lr_scheduler,
#         warmup_ratio=args.warmup_ratio,
#         warmup_steps=args.warmup_steps,
#         learning_rate=args.learning_rate,
#         num_train_epochs=args.num_train_epochs,
#         save_steps=args.save_steps,
#         eval_steps=args.eval_steps,
#         dataloader_num_workers=args.num_workers,
#         metric_for_best_model=args.metric_for_best_model,
#         greater_is_better=args.greater_is_better,
#         report_to=args.report_to,
#         generation_max_length=256,
#         generation_num_beams=5,
#         sortish_sampler=True,
#         group_by_length=True,
#         include_tokens_per_second=True,
#         include_num_input_tokens_seen=True,
#         dataloader_prefetch_factor=2,
#     )
#
#     # Create Trainer instance
#     trainer = Seq2SeqTrainer(
#         model=model,
#         args=training_args,
#         data_collator=data_collator,
#         train_dataset=train_dataset,
#         eval_dataset=eval_dataset,
#         compute_metrics=seq2seq_compute_metrics,
#         callbacks=[
#             EarlyStoppingCallback(
#                 early_stopping_patience=args.patience,
#                 early_stopping_threshold=args.threshold,
#             )
#         ],
#     )
#
#     print(f" | > Starting training ...")
#
#     try:
#         trainer.train()
#     except KeyboardInterrupt:
#         print(f" | > Training interrupted ...")
#
#     # this will only save the LoRA adapter weights
#     model.save_pretrained(args.output_dir)
#
# if __name__ == "__main__":
#     parser = get_arg_parse()
#     args = parser.parse_args()
#
#     main(args)
